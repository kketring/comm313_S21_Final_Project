# %% [markdown]
# # Assessing Language Used When Tweeting About the NCAA

# %% [markdown]
# How do people talk about the NCAA on Twitter? Is it positively or negatively? What are common words and sentiment associated with the NCAA?

# %% [markdown]
# <b>Kayla Ketring
#
# COMM 313 Final Project<b/>

# %% [markdown]
# <b>Background</b>
#
# The National Collegiate Athletic Association, also knows as the NCAA, has been a sexy topic in recent years. The purpose of the NCAA as stated on their website is to "safeguard the well-being of student-athletes and equip them with the skills to succeed on the playing field, in the classroom and throughout life." Since 2015, the NCAA has been faced with many tough decisions revolving around college sports and collegiate athletes. Detailed below are a handful of the major events, decisions, and court cases against the NCAA since 2015.
#
# In 2015, Ed O'Bannon, a former UCLA basketball player sued the NCAA and filed a class-action lawsuit claiming that the athletes should be compensated for the use of their images and likenesses in television advertisements, video games, apparel, and other materials. The O'Bannon vs. NCAA lawsuit sparked an endless battle for NCAA athletes to obtain compensation for their name, image, and likeness being used by universities, companies and organizations without proper compensation. The battle is still ongoing and the Supreme Court is set to make a decision in June, 2021.
#
# In 2018, The NCAA spent $13.5 million more for the men's March Madness basketball tournament than it did for the women's.
#
# In 2019, California passed a legislation that would prohibit schools from punishing atheltes who accept endorsement money while in college, The legislation is set to start in 2023 and has not been accepted by the NCAA, as it declared that the legislation is an "existential threat" to college amateur sports. The debate is continuously ongoing as 2023 is nearing closer and more states are nearing a decision to join California.
#
# In the 2021 the Men's March Madness "bubble" in Indianapolis was well-equipped with an over-sized gym room full of squat racks, benches, barbells, and racks. However, over in San Antonio where the Women's March Madness "bubble" was located, there were only yoga mats and a couple dumbbells. The NCAA Title IX rule states that, "No person in the United States shall, on the basis of sex, be excluded from participation in, be denied the benefits of, or be subjected to discrimination under any education program or activity receiving Federal financial assistance." In simple terms, Title IX ensures that women's and men's athletics receive equal benefits across the board.  The inequality in resources provided for the womens' teams was not only embarrassing for the NCAA, but also discouraging and down-right unlawful. The NCAA apologized and quickly fixed the women's gym, but such a disaster caused the collegiate world to ask, "didn't they know this was a violation of title IX?"
#
# The NCAA has been challenged and continues to be challenged by athletes, universities, and even politicians to adapt and change, but NCAA decisions continue to ebb and flow in helping athletes but also hurting them.

# %% [markdown]
# <b>Guiding Question</b>
#
# Since 2015, has sentiment about the NCAA on Twitter become more negative?

# %% [markdown]
# <b>The Corpus</b>
#
# text

# %% [markdown]
# # Setup and Load Data

# %%
import snscrape.modules.twitter as sntwitter

import json
import os
import datetime
from nltk.tokenize import TweetTokenizer, WordPunctTokenizer
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
def load_tweets(tfile):
    
    tweets = []
    for line in open(tfile):
        try:
            tweets.append(json.loads(line))
        except:
            pass
        
    return tweets

# %%
def process_tweet(tweet):
    
    toks = tt.tokenize(tweet['text'])
    tweet['tokens'] = toks
    
    
    tweet['Valence']=0
    tweet['Dominance']=0
    tweet['Arousal']=0
    
    tweet['VAD_toks']=[]
    
    for t in toks:
        if t.lower() in NRC_VAD.keys():
            scores = NRC_VAD[t.lower()]
            scores['tok']=t
            
            tweet['Valence']+=scores['V']
            tweet['Arousal']+=scores['A']
            tweet['Dominance']+=scores['D']
            
            tweet['VAD_toks'].append(scores)
    
    
    for dimension in ('Valence','Arousal','Dominance'):
        if len(tweet['VAD_toks'])>0:
            tweet[dimension] /= len(tweet['VAD_toks'])

# %%
def download_query_tweets(query, date_since, date_until, max=1000):
    print(f"Downloading tweets for query: '{query}' from {date_since} to {date_until} (max of {max})")

    tweet_list = []
    
    query = f'{query} since:{date_since} until:{date_until}'
    
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
        if i>=max:
            break
    

        tweet_dict = {
            'id': tweet.id,
            'created_at': tweet.date.strftime('%Y-%m-%d %H:%M'),
            'text': tweet.content,
            'username': tweet.username
        }

        tweet_list.append(tweet_dict)
        
    return tweet_list

# %%
DATA_DIR = 'data/ncaa'

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

since = "2020-03-08"
until = "2020-03-15"
queries = [ 'ncaa', "#ncaa"] 

for query in queries:
    tweet_list = download_query_tweets(query, since, until)
    
    outfilename = "{}/{}_{}_to_{}.json".format(DATA_DIR, query.replace(' ','_'), since, until)
    
    print('\t retrieved {} tweets...\n'.format(len(tweet_list)))
    with open(outfilename,'w') as out:
        out.write(json.dumps(tweet_list))
# Out:
# Downloading tweets for query: 'ncaa' from 2020-03-08 to 2020-03-15 (max of 1000)
# 	 retrieved 1000 tweets...
#
# Downloading tweets for query: '#ncaa' from 2020-03-08 to 2020-03-15 (max of 1000)
# 	 retrieved 1000 tweets...

# %% [markdown]
# # I'm assuming I have code in here that does not need to be in here and is taking up unnecessary space. Are you able to highlight what can be deleted? Or just delete it?

# %%
ranges = [("2020-03-08",'2020-03-08'),("2020-03-08",'2020-03-08')]

# %%
def Get_query(date_range,queries):
    since,until = date_range
    year = since.split('-')[0]
    if not os.path.exists('data/{}'.format(year)):
        os.makedir('data/{}'.format(year))
        
    for query in queries:
    tweet_list = download_query_tweets(query, since, until)
    
    outfilename = "{}/{}_{}_to_{}.json".format(DATA_DIR, query.replace(' ','_'), since, until)
    
    print('\t retrieved {} tweets...\n'.format(len(tweet_list)))
        
    return{"date-range":date_range,"results":tweet_list}

# %%
for date_range in ranges:
    data = Get_query(date_range,['#ncaa',''])

# %%
ncaa_data = json.load(open('data/ncaa/ncaa_2020-03-08_to_2020-03-15.json'))

# %%
ncaa_data
# Out:
# [{'created_at': '2020-03-14 23:59',
#   'id': 1238978207669501953,
#   'text': '@FootbaIl_Tweets NCAA, the others all fall behind Madden. But you also forgot the Dreamcast NFL game, that was a cool game too.',
#   'username': 'StephenMaxO79'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978159296614400,
#   'text': 'NCAA https://t.co/UM8CrK83vc',
#   'username': 'D2_GDC'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978152149291008,
#   'text': '@FootbaIl_Tweets NCAA 14, Madden 08, NFL Blitz street v2. Best in they class all the other years suck ass',
#   'username': 'kramer_dan'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978147841789953,
#   'text': '@JonRothstein @KentuckySports Sometime in the next two seasons Iona will be put on NCAA probation, bet on it.',
#   'username': 'KaboomLip'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978147258793984,
#   'text': 'damn NCAA over tho 😥',
#   'username': 'CrocutaMane'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978106850869248,
#   'text': 'NCAA off tops https://t.co/VB3u8gjabJ',
#   'username': '__lc3_10'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978080015777792,
#   'text': 'At least release the NCAA bracket so I can fill it out 200 times😂',
#   'username': '_jward40'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978075364188160,
#   'text': "@VancityMan99 @SharpSkatesVan Yikes!!  Max Performance Sports is where it's at.  This is my third jersey they've done, including special ordering the NCAA twill kit.  They're great!",
#   'username': 'samanthacp_'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978068296990722,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/amVHnxndJr via @Change',
#   'username': 'BABYANGELJMG'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978055391064064,
#   'text': 'In light of the current state of our nation and precautions to keep everyone safe, the NCAA has issued a dead period for recruiting ‼️ Recruits , coaches will be checking emails during this time. Please stay safe and healthy during this time! #FSUWLAX 🐾 https://t.co/ocMOKLtp5O',
#   'username': 'FrostburgWLax'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978035724029952,
#   'text': '@PaulONeill1972 @espn @FOXSports @SportsCenter @SInow @MLB @NFL @NBA @NHL @MLS @WNBA @ShowtimeBoxing @WWE @Wimbledon @TheMasters @NASCAR @PGATOUR @Olympics @NCAA https://t.co/CDtHiNMdUD',
#   'username': 'thegunnah'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978020313976833,
#   'text': 'So NCAA granted a year of eligibility for spring sports, does that mean the same for HS sports',
#   'username': 'riley_skone'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238978009278930945,
#   'text': 'Why is this a question? NCAA. https://t.co/Du2OsAfZkW',
#   'username': '_joeearl'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238977997044092930,
#   'text': 'This team had DUDES!!! Regular season conference champs, conference tourney champs and NCAA tourney East Regional champs. As if I needed another reason to miss basketball this time of year https://t.co/m7dEV9mntA',
#   'username': 'KBriggs_24'},
#  {'created_at': '2020-03-14 23:59',
#   'id': 1238977978786361347,
#   'text': '@BigEZ @WLKY If CBS doesn’t play the top 64 NCAA games of all time starting next Thursday they are tone deaf to the situation',
#   'username': 'BMay2043'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977934284619776,
#   'text': '@charliekirk11 @NCAA Dr. Fauci recommends restricting domestic travel for obvious reasons. However, trump is ignoring him like he has been ignoring expert advice since Jan. 3. Getting re-elected has been trump’s priority over the health of Americans.',
#   'username': 'politicallynau1'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977857981997056,
#   'text': 'Just play NCAA tourneys, NBA playoffs, etc... From decades ago in their entirety https://t.co/KHp5d1Bls9',
#   'username': 'CaptainQuint'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977797927862273,
#   'text': 'Can they Atleast play last years NCAA tournament on ESPN so we can atleast feel like it’s on 😩😩😂😂',
#   'username': 'Chrispy_Kickzz'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977792189980673,
#   'text': '@FootbaIl_Tweets NCAA and it’s not even close',
#   'username': 'PigScrewy'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977785034690561,
#   'text': '@charliekirk11 @NCAA It should be called the sleepy joe virus because most people that get it don’t even know it.  We have shut down our country over a virus that doesn’t do anything how did this happen?  MSM?',
#   'username': 'Michael96654721'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977773546471431,
#   'text': 'Win a Trip for 4 to the 2021 NCAA March Madness Men’s Final Four -- Includes $6,400 in #Cash ($27,700)!\n\n#NABISCO #TogetherWeFan #Sweepstakes #MarchMadness #win #contest #giveaway #sorteo #dinero #NCAAbasketball #Final4 #FinalFour\n\nhttps://t.co/hajSe6Gsym',
#   'username': 'Win_Win_Now'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977746157686786,
#   'text': '@ChallengeObps @sdtitmas @espn @FOXSports @SportsCenter @SInow @MLB @NFL @NBA @NHL @MLS @WNBA @ShowtimeBoxing @WWE @Wimbledon @TheMasters @NASCAR @PGATOUR @Olympics @NCAA Was that Michael Cooper that Dr. J dunked on?',
#   'username': 'PaulONeill1972'},
#  {'created_at': '2020-03-14 23:58',
#   'id': 1238977730474958848,
#   'text': 'CBS, TNT, TBS, TruTV should play classic NCAA Tourney games in order of how we would see them! Play the 4 top “play-in” games of all time, followed by 32 classic 1st rd games, 16 second rd games, 4 Elite Eight games, 2 Final Four games and a National Championship game!',
#   'username': 'ChrisHyppa'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977688808894469,
#   'text': '@BernardKerik Or, cancel cable. No Masters, NCAA basketball tournament, NHL, or MLB, so why not test cutting the cable now that Fox News has thrown in with PMSNBC and CNN. Now’s the time to try it.',
#   'username': 'ccharrier'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977667833245696,
#   'text': 'Also interestingly, there are four undefeated teams left in this season, Florida State, Ohio State, Louisville and Boise State (#1-4 in that order, all 9-0). NCAA 14 only has a national title game, no 4-team playoff. Someone might be left out.',
#   'username': 'ILM_Ryan'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977595221454848,
#   'text': 'https://t.co/lnXUzhVIGV #NCAA',
#   'username': 'raiderway83'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977558491865088,
#   'text': 'The Florida Senate calling FSU the 2020 NCAA men’s basketball champs is like Bob Cobb calling himself the “The Maestro” #seinfeld https://t.co/jsxGN91UH9 https://t.co/xCyfnAIVuq',
#   'username': 'danwindels'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977537671401473,
#   'text': '@charliekirk11 @NCAA Or close the airports....',
#   'username': 'slackscom'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977522047614976,
#   'text': 'At least I got a perfect ncaa bracket thus far',
#   'username': 'c_oso34'},
#  {'created_at': '2020-03-14 23:57',
#   'id': 1238977513147322370,
#   'text': '2020 NCAA Champion shocks the world in the biggest upset in Division I history ever recorded 😳 https://t.co/1GO92M2hOK',
#   'username': 'blackmagic69961'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977441273712641,
#   'text': 'I love the intern for a site on pro football, which I love but is equally or more barbaric than MMA when viewed outside of the family friendly marketing by the NFL/NCAA, is attempting to be the moral arbiter on what sports should or shouldn’t be operating. Also, it’s airborne. https://t.co/u4sSH4MaL5',
#   'username': 'WhoIsLoganG'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977430292967425,
#   'text': "@ChefBoyArGreen Well you just got your 1,000th like from me, so I am happy I could help with that! 😉 Hopefully the @NCAA does the right thing and you get another year. But you would have had it if they didn't cancel the tournament.",
#   'username': 'mjrhoosier'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977425368920070,
#   'text': '@BarstoolBigCat NCAA closed door preseason games. Those are a thing.',
#   'username': 'Will_Hodge51'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977387221655553,
#   'text': "The @ufc needs a fighters union that fights for fighters labor rights. Seeing sponsors disappear from trunks can't be helping anyone's bottom line except Dana White. Seems similar to the NCAA not letting players profit from their own likenesses.",
#   'username': 'NateWeberActual'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977381672595457,
#   'text': '@MovementMiyagi Without the crowds it’s just two guys fighting. Pure. Was kind of interested in seeing the NCAA tournament without crowds.',
#   'username': 'ellisj2'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977375993561088,
#   'text': '@katiebakes Definitely a bummer but in grand scheme of things a blip on the radar.  Hopefully that’s how people start thinking with modifying behavior to accelerate containment.  Feel way worse for senior ncaa athletes and of course those affected by the virus.',
#   'username': 'AxelBerg13'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977318682574850,
#   'text': 'Coronavirus was created by the NCAA to stop LSU from winning another natty this year',
#   'username': 'ricky__bryant6'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977256237592576,
#   'text': '@dc_mma @danawhite @ufc @dc_mma we need to hear the "2" from the NCAA Wrestling tournament for normal to come back my man',
#   'username': 'rkapaku'},
#  {'created_at': '2020-03-14 23:56',
#   'id': 1238977209257340928,
#   'text': '@DickieV @Rick_Pitino @IonaGaelsMBB @TheGarden @StJohnsBBall @NYPost_Brazille Dick, sorry that you and the NCAA approve of Pitino coaching basketball again after his firing for unethical behavior.  You my friend and the NCAA are just as low as Pitino. Pitino is not fit to coach young men college basketball because of his immoral behavior.',
#   'username': 'GeorgeHimes2'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977200461840388,
#   'text': '@WillB25Bomber @charliekirk11 @NCAA Dumb to fly. Suicide flights',
#   'username': 'GordonT21023756'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977184292839425,
#   'text': 'Reveal the bracket tomorrow &amp; make us suffer more @ncaa',
#   'username': 'bturner23'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977163724042241,
#   'text': 'Day 5(?) of not understanding why the NCAA couldn\'t postpone like everyone else and instead said "Let\'s just cancel everything"',
#   'username': 'HerbertBurner'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977155775651840,
#   'text': '@CFFleague @walkoff9 @bordersroad Literally every model cites between 150-2mm but hey who should we trust? Doctors, scientists, and public health experts or the founder of the #1 ncaa fantasy league https://t.co/guKN0MjgBY',
#   'username': 'GordonDFS'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977150776041473,
#   'text': 'Some NCAA conference tournament championship games would be nice to watch right now. https://t.co/fUYlE9G3P8',
#   'username': 'UtePadre'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977123676815361,
#   'text': "@sfloridastorm @NBA @NHL @NCAA @MLB @MLS @NFL That's a good one!!",
#   'username': 'TheValuesVoter'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977086565433344,
#   'text': "Rick Pitino to Iona - Don't forget Jim Valvano coached there;  pulled off an amazing recruiting job by getting Jeff Ruland to New Rochelle.  I was at the Garden in 1980 when Iona beat Louisville. Cards won title that year. Gaels lost to G'Town by 3 in 2nd round of NCAA https://t.co/HXWFxt9fcA",
#   'username': 'CoachFinamore'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977053069914113,
#   'text': '@PeteThamel Didn’t realize all the connections. \nNo doubt this is a good hire although he will have to maintain the level of play ( NCAA ). A hire now may be a preemptive strike to a “ show cause “.',
#   'username': 'WVwings'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977041380151296,
#   'text': '@SethDavisHoops Lost in all of this will be the job Cluess did at Iona. 6 NCAA appearances in 9 years at Iona. Been a fan from afar of his offensive ingenuity and how much he got out of his players every year.',
#   'username': 'hustonfive'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977016189390848,
#   'text': '@BuckeyeMel8699 What’s next? 🚫ichigan governor names Wolverines NCAA football champs? 🤦🏻\u200d♂️',
#   'username': 'JeffFreeman1'},
#  {'created_at': '2020-03-14 23:55',
#   'id': 1238977014805213185,
#   'text': '@EASPORTS perfect time to bring back NCAA Football...',
#   'username': 'CamoBro570'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976931699347467,
#   'text': 'Since everyone is quarantined and no #ncaa or #nba...the #ps4 server is dead ass like: https://t.co/2zIHErEGWY',
#   'username': 'His_Majesty_J'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976862753259520,
#   'text': '@EliPence @DavidPJablonski @BarstoolBigCat @barstoolsports @NCAA @marchmadness @FinalFour This will keep me going for a few days. Thank you.',
#   'username': 'HaKuhnna_Matata'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976860299673603,
#   'text': '@catturd2 Dude- they fkn canceled the NCAA tournament... unreal overreaction',
#   'username': 'Cammad18'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976832080412678,
#   'text': '@DavidThomsen15 @MrBill108 @charliekirk11 @NCAA @realDonaldTrump Yes but DONT CAVE IN because Democrates=bad\nDONT CAVE IN because of Reason, otherwise\nthey will still control the narrative',
#   'username': 'VladsRepoman'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976803101949954,
#   'text': 'Thank you @NBA @NHL @NCAA @MLB @MLS @NFL for strengthening marriages everywhere. 🤣\n\nGot to keep your sense of humor in trying times. 😉😎 @TheValuesVoter thought if you. https://t.co/GPmfpv6bqb',
#   'username': 'ChooseTruth365'},
#  {'created_at': '2020-03-14 23:53',
#   'id': 1238976700999970817,
#   'text': 'Saturday Night with No NBA or NCAA games 🤦🏾\u200d♂️',
#   'username': 'callmebasko'},
#  {'created_at': '2020-03-14 23:53',
#   'id': 1238976612089171970,
#   'text': '@charliekirk11 @mitchellvii @NCAA Is this Denver?',
#   'username': 'SFerg38'},
#  {'created_at': '2020-03-14 23:53',
#   'id': 1238976601985093635,
#   'text': 'UK beating Duke in the NCAA finals by 11 with 4 to go, but Givens  just picked up his fourth foul.',
#   'username': 'stevie_brett'},
#  {'created_at': '2020-03-14 23:53',
#   'id': 1238976552450342917,
#   'text': '@djskoolboi33 @gooddays22 @Ian_OConnor @MBrownstein89 Yes the NCAA is the pinnacle of ethics and morality....',
#   'username': 'MKennedy872'},
#  {'created_at': '2020-03-14 23:52',
#   'id': 1238976452059639809,
#   'text': "Would have been cool today to see UVM earn another automatic NCAA bid followed by (my niece's) Fair Haven girls basketball completing their undefeated defense of last year's D2 State championship. #NotChampionshipSaturday #boo",
#   'username': 'thebiggreekvt'},
#  {'created_at': '2020-03-14 23:52',
#   'id': 1238976359050833920,
#   'text': '@Tbrdfx96Shelly @charliekirk11 Thank you for your service, but your sacrifice to your country doesn’t have anything to do with the NCAA or March madness.',
#   'username': 'jholmesak'},
#  {'created_at': '2020-03-14 23:52',
#   'id': 1238976327233032194,
#   'text': '@HVSportsReport @DalyDoseOfHoops Maybe HVsports can look under the cover at why #marist is consistently in the basement of not just the #maac but all of #d1 ncaa basketball.',
#   'username': 'FrederickDever1'},
#  {'created_at': '2020-03-14 23:52',
#   'id': 1238976294123118594,
#   'text': 'Here is a playlist I made up of the best 63 NCAA Tournament games I could find... MARCH MADNESS LIVES!!!!!!!! 2020 NCAA Tournament https://t.co/UaV1c9mr6X via @YouTube',
#   'username': 'LoganGreenwell'},
#  {'created_at': '2020-03-14 23:52',
#   'id': 1238976289878544384,
#   'text': 'https://t.co/6xxaX00uzk weighing release of 68-team bracket despite cancellation of 2020 NCAA Tournament over coronavirus#BBN #Wildcats',
#   'username': 'WildcatNewsfeed'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238976189613715462,
#   'text': '.@easports plz release a version of NCAA March Madness so we can play it out ourselves',
#   'username': 'matt_hartley_'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238976131107360768,
#   'text': 'On the court, on the NCAA and on his wife... https://t.co/5KZLuzOcms',
#   'username': 'RobbinsDick'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238976075398447104,
#   'text': '@charliekirk11 @mitchellvii @NCAA Well you see, to the DNC Alt-Left those in the NCAA are valuable prop... er players, while these folks are not.',
#   'username': 'terrorjester'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238976048999682050,
#   'text': '@ChetCrooks @EASPORTS Bring back NCAA Football EA',
#   'username': 'josiah01803642'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238976012005912576,
#   'text': '@nascardiva4 @charliekirk11 @NCAA Time not to be n crowds?',
#   'username': 'GordonT21023756'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238975998147821568,
#   'text': 'i dont know why but i feel like crying i guess cause there no live sports on tv i guess man i miss my auburn tigers i hate the season is over for them and for every team that has made it to the ncaa',
#   'username': 'justinjones2015'},
#  {'created_at': '2020-03-14 23:51',
#   'id': 1238975976454881280,
#   'text': 'I want it to be known @IowaHoops would have won the NCAA tourney this year.',
#   'username': 'Hawkeye_Drew'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975929868828672,
#   'text': 'Hey @wlky, do you get rights to archived NCAA Tournament Basketball games on CBS? If so, next week would be the time to air every team’s last championship!',
#   'username': 'BigEZ'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975842610487297,
#   'text': '@JohnnyBlues13 @charliekirk11 @NCAA i got a travel alert stating that Denmark was shutting down their borders.',
#   'username': 'iamthatperla'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975801552502787,
#   'text': "@steve_sez_3MTA3 Exactly. Why I am standing 6 feet back from customers at my job. Was supposed to take off 3 days next week for Purdue possibly in the NIT and on Thursday for NCAA Tournament. Still doing it after those events were cancelled because it's probably a good idea to stay away if I can",
#   'username': 'FauxMcCaskey'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975801183416320,
#   'text': "@NYGHoops @NCAA @espn That's like saying  you was awarded money in a law suit but can't collect because  the defendant filed for bankruptcy..",
#   'username': 'Hoopsking1968'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975774197194761,
#   'text': 'May Madness would be great! #MarchSadness2020 #NCAA #NCAATournament',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975773664350208,
#   'text': 'In a time when this country needs its sports to lift up our spirits &amp; keep our sanity, instead, they run &amp; hide! @marchmadness @NCAA FAIL! No one should support these fake frauds! @NBA @CBSSportsCBB @NHL @MLB',
#   'username': 'dkg_hilife'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975772263682049,
#   'text': 'From basketball to baseball to softball to hockey to wrestling and all other sports. These kids have worked hard all their lives for this moment. Competing for a National Championship is the ultimate dream for many. Maybe the NCAA can re-evaluate their decision? April Madness and',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975769067610113,
#   'text': '2 days later and I am still heartbroken about the @NCAA decision to cancel the tournaments for all winter and spring sports. Postponing and reevaluating in a few weeks would have been the right decision. These kids have trained and worked their whole lives for this moment.',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975717658017793,
#   'text': '@Pantingdeer5 @Change @NCAA Student athletes are eligible to play sports for 4 years.  If they are on a team all 4 years of their undergraduate program and continue on to graduate school, they are not eligible to play a 5th year.  They are asking if they continue on to graduate school that they be eligible',
#   'username': 'finoccj'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975693628878856,
#   'text': '@johnpavlovitz My SON!!! He just found out his college track season has been ended by the NCAA, but he remains positive❤️❤️ Sad, but positive',
#   'username': 'JoeyIske'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975678843846657,
#   'text': '@charliekirk11 @NCAA Why so many people in airport. Dangerous to fly? At any price.',
#   'username': 'GordonT21023756'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975673949134850,
#   'text': '@JonRothstein Please for the love of God..I hope they go to the NCAA tournament and play Louisville😂😂😂',
#   'username': 'TrueblueCATfan'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975663601680384,
#   'text': '3/16: 2,600 cases\nThere’s reasons why shit is cancelled. Imagine NCAA continuing as forecast shows? One of the biggest tournaments in the US. Call it overreaction but I’d rather this shit go away than continuing to affect jobs, 401Ks, my stocks. Let this end sooner than later. https://t.co/73nqd5xQ0U',
#   'username': 'Louie_V_23'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975637609742336,
#   'text': '@Bobby71582221 @charliekirk11 @cdm5866 @NCAA https://t.co/xLRuGipefu',
#   'username': 'iamthatperla'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975621151240193,
#   'text': 'In the news: FL Senate Declares FSU Champs: Florida Senate passes resolution naming Noles 2020 basketball national champions after NCAA tourney was canceled https://t.co/Ra0HYTyyPY',
#   'username': 'MBsandsKU'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975506801885184,
#   'text': '@IonaGaelsMBB BIG MISTAKE by IONA.  Pitino should not be allowed back  into coaching basketball because of his low life performance that got him fired.  NCAA is totally not ethical in practice.',
#   'username': 'GeorgeHimes2'},
#  {'created_at': '2020-03-14 23:49',
#   'id': 1238975505413611523,
#   'text': '@charliekirk11 @mitchellvii @NCAA Stupid people who warch too much Fox News.',
#   'username': 'oaklandzoo22'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975362710867981,
#   'text': "@Coach_KBruno @BrandonFurrerRU @RFootball 2021 David Tibbs OT/DT \n@Davidtibbs77\n\n6'7 270\nUnweighted NCAA GPA 2.78/Overall 3.2\nSAT 790 retaking March 2020\nACT taking April\nbench 260\nsquat 475\nclean 230\ndead 405\n40 5.1\n\nEmail: davidtibbs10@gmail.com\nPhone: (727) 871 1943",
#   'username': 'DavidTibbs77'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975298269401088,
#   'text': '@DanSileoShow @ionacollege @RealPitino @NCAA @marchmadness Let him coach',
#   'username': 'FredoDooley'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975281395691520,
#   'text': 'After watching 12 NCAA basketball games this year, I feel I’m qualified to declare Ohio State and Arizona State as co-national champs for men’s basketball. Congrats guys!',
#   'username': 'TonyEYoung'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975270541033472,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/jWSY0LTCqD via @CdnChange',
#   'username': 'rjj_12'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975218187632640,
#   'text': '@VTsportsimages @cvugirlshoops NCAA and HS aren’t the same. Students aren’t on campus. They aren’t at school to practice. We may not be either but first step will most likely be postponing. Then go from there.',
#   'username': 'RedhawkXC1'},
#  {'created_at': '2020-03-14 23:48',
#   'id': 1238975204405194753,
#   'text': "For college hoops fans in this area, I'll have feature on Altoona native &amp; Saint Francis alum Mike Iuzzolino in tomorrow's @AltoonaMirrorPA\nIuzzolino is an assistant at Robert Morris and helped Colonials to the NEC championship and berth in NCAA Tournament. Check it out tomorrow.",
#   'username': 'CoryGiger'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975168241790977,
#   'text': 'Anyone that thinks the NCAA Football and NFL Seasons are NOT getting pushed back are kidding themselves. #Covid19',
#   'username': 'Sidelines_PSU'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975142472146946,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/YNROTThloD via @Change',
#   'username': 'MarkMo12'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975121647427584,
#   'text': '@NYGHoops @NCAA @espn Mixed emotions about that.',
#   'username': 'Hoopsking1968'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975114349367298,
#   'text': '@ACPressHuba Show some pride &amp; lift up this countrys spirits unlike the @marchmadness @NCAA @NBA',
#   'username': 'dkg_hilife'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975052248383488,
#   'text': 'Update: I’ve had Mexican leftovers, 6 Girl Scout cookies, watched 8 episodes of Schitts creek and all 3 episodes of Dave. About to buy NCAA 07 on eBay.....I would watch a Big Sky conference game right now if it was on. #Day3NoSports',
#   'username': 'IndiGator'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238975020208095234,
#   'text': '@charliekirk11 @NCAA Bring back sanity to our nation. https://t.co/l9hhHrE1Zg',
#   'username': 'Whitman26478478'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238974997064015872,
#   'text': 'Charlie Kirk Freaks Out About NCAA Cancellation, NCAA Still Plans to Grant an Additional Year of Eligibility to Some Athletes https://t.co/S77h6NYm7N',
#   'username': 'bigleaguepol'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238974957721444352,
#   'text': '@Hoopsking1968 @NCAA @espn But at least they can say they made it, but tourney was not played.',
#   'username': 'NYGHoops'},
#  {'created_at': '2020-03-14 23:47',
#   'id': 1238974951534682112,
#   'text': 'NCAA built and spent tournament safety net https://t.co/uQ33DmZL7C https://t.co/7qQAhFRwgi',
#   'username': 'ExBulletinUk'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974932287197187,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back https://t.co/wGDOu6MLUL via @Change',
#   'username': 'HamptonsKiley'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974878620848129,
#   'text': '@charliekirk11 @mitchellvii @NCAA Which airport?',
#   'username': 'RobertaRogers07'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974823453175814,
#   'text': 'NCAA cancels Division II Indoor Track &amp; Field Championships - Brownwood Bulletin https://t.co/vlG4KCmjk0',
#   'username': 'TRF_News'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974781422100482,
#   'text': '@simpy2009 @charliekirk11 @NCAA 😂',
#   'username': 'TeddyTed213'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974766779899904,
#   'text': '@NCAA  me and you both know if this was during football season nothing would be cancelled 🤔🤔',
#   'username': 'Nate_dupree6'},
#  {'created_at': '2020-03-14 23:46',
#   'id': 1238974721636605956,
#   'text': "@Delta Delta isn't refunding money spent on flights that were booked for travelers attending cancelled NCAA events due to a global pandemic. They are irresponsible and greedy! fly elsewhere",
#   'username': 'kurtwilly6778'},
#  {'created_at': '2020-03-14 23:45',
#   'id': 1238974636911722496,
#   'text': 'There is no way the CFP would have been cancelled #omaha #COVIDー19  #ncaa',
#   'username': 'KennyLedford21'},
#  {'created_at': '2020-03-14 23:45',
#   'id': 1238974519387336705,
#   'text': 'Going to start a dynasty in NCAA Football 13 tonight...\n\nNon power 5 suggestions?',
#   'username': '1TimMurray'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974405885083648,
#   'text': '@TheWildcaster @JustinESports Because when you think about it?..... the programs get money for making the tournament through a shared distribution from the conferences and now that won’t be paid the NCAA will just keep the money 💰',
#   'username': 'moffet_russell'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974357902368769,
#   'text': 'no ncaa tournament, so I guess a pandemic tournament.  no doubt the black death, Spanish flu,,and Asian flu definite final 4, but aids takes the title.....they have magic',
#   'username': 'Jamiebroman2'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974338444951553,
#   'text': '@LauraRutledge @espn @ABC I think we should have some online ncaa basketball. Best players from each team go head to head on PlayStation or whatever. We can decide March madness, NBA and NHL Stanley cup playoffs while we’re all trapped inside. Get espn some ratings. 😂',
#   'username': 'IamSLingo'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974309001035776,
#   'text': "@FrederickDever1 @DalyDoseOfHoops Cheated on his wife (in a restaurant, no less), strippers in the dorm at Louisville, NCAA Notice of Allegations bomb soon to go off at Louisville, among other things. If that's an injection of respect, I'll pass.",
#   'username': 'HVSportsReport'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974280475586560,
#   'text': '@ncaa it is time to do the right thing. Give seniors who did not get to finish their seasons another year of eligibility. Most won’t use it but give it to those who want it. @Bwise50',
#   'username': 'Indysaved'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974245331501058,
#   'text': '@LilyJoy65293613 @charliekirk11 @NCAA I just better be able to go. Not booked til may 30...but im NOT missing going to see my first grandbaby!',
#   'username': 'nascardiva4'},
#  {'created_at': '2020-03-14 23:44',
#   'id': 1238974194328702976,
#   'text': '@VTsportsimages If there was a prayer for spring sports, they would have postponed the basketball championships for 2 weeks. The NCAA cancelled, the VPA will cancel.  Sadly, not a prayer.',
#   'username': 'cvugirlshoops'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974155162337286,
#   'text': "@theDudeofWV @MarkKochenderfe Off topic... I'm watching the KSU game and Campbell had a big game.  Did he apply to the NCAA for another year of eligibility?",
#   'username': 'letsgomtnrs'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974152238907393,
#   'text': 'Could you imagine how much money @EASPORTS and the @NCAA would make if they released NCAA Football 2020 for Xbox1/PS4?',
#   'username': 'PastorBeef'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974114594844672,
#   'text': "I totally agree with James. The difference is NCAA can allow seniors an extra year of eligibility. We are hoping to let our seniors to put that uniform on 1 last time. I trust that Rob and Rich at CIF-SS share our sentiment. # Let's Play. https://t.co/kQ7W42d6KT",
#   'username': 'PDAztecsports'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974100481212417,
#   'text': 'The @NCAA Men’s Final Four would be Saturday of that week and the National Championship game on Memorial Day evening. \nWe need to get this out, before some of these college stars engage with or sign with an agent and become immediately ineligible. Come on @NCAA fix it!',
#   'username': 'ReallyOpenMike'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974072937164801,
#   'text': 'Miles took the time (on possibly the busiest and worst day of his career) to come to the Coop to hit batting practice with the team. Minutes later we received the news from the NCAA that all championships had been canceled. This gesture of support meant so much to all of us. https://t.co/6FDUYm2QHb https://t.co/6pd0eW2bfD',
#   'username': 'coachshehan'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238974003643060225,
#   'text': 'This is what happens when two sportscasters can’t work: we’ve put together a BEST MOVIE/TV DOGS bracket to replace your NCAA brackets. But before we can post, @Dario_Melendez is protesting SlinkyDog’s inclusion. https://t.co/F3m409SmjB',
#   'username': 'JenLada'},
#  {'created_at': '2020-03-14 23:43',
#   'id': 1238973980482195461,
#   'text': '@charliekirk11 @NCAA No, Charlie.\nPeople need to return home.\nPretty soon, air travel may be suspended too.\nDon’t be stupid.',
#   'username': 'juppteuer'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973934453874688,
#   'text': '@stschoberg @marchmadness @NCAA I like it!',
#   'username': 'TaraScho'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973909732659200,
#   'text': 'To hockey to wrestling and all the other winter sports. Competing for a National Championship is an ultimate dream for many. Maybe the NCAA can re-evaluate their decision? April Madness or May Madness would be great! #NCAATournament #MarchSadness2020 #NCAA',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973902384136192,
#   'text': '@OTHwildcats NCAA runner up one year, 38-1 and a FF appearance the next. That’s not garbage.',
#   'username': 'TBrown_80'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973826123390976,
#   'text': '@benholden28 @RedditCFB It doesn’t matter conference you play for in College Basketball, if you go undefeated you will make the NCAA March Madness Tournament. You will be given the opportunity to compete for a National Title for your school. You will not be given an opportunity in College Football.',
#   'username': 'CFBKnights'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973816811827200,
#   'text': 'NCAA to hold March Madness without fans due to coronavirus https://t.co/x7Q6r6MTOm #SmartNews',
#   'username': 'Timothy35774658'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973804795310081,
#   'text': '@kenpomeroy I want to disagree but I also would have bet my 401(k) (the $10 left in it) that they would have never cancelled an NCAA Tournament for any reason.',
#   'username': 'datdudepp'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973645558407168,
#   'text': 'Me watching the NCAA selection show today. 😢 #BBN  Young guys please come back! https://t.co/gge9jw8E6J',
#   'username': 'Bowling737'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973577728319489,
#   'text': 'The aftershocks of cancelling March Madness, the NCAA’s billion-dollar lifeblood, will reverberate far beyond sports https://t.co/SjSbDUpC5k',
#   'username': 'StarSports'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973550905655299,
#   'text': 'NCAA Suspends In-Person Recruiting Until April 15th https://t.co/9w2p6BeniH',
#   'username': 'NCSAEllen'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973505041059841,
#   'text': "Anthony Grant and Dayton beat Gonzaga in Sportsline's NCAA Tournament simulation to capture the 2020 National Championship, their first in program history in their second all-time Final Four appearance. https://t.co/FxMeRB5tbp",
#   'username': 'CrestwoodSupt'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973499609415680,
#   'text': "Well after everything's that's transpired with Collegiate Baseball and the NCAA the last few days, our 2020 team pictures arrived in the mail today. Not sure if we should 😂 or 😢 #GoCoogs #M64 and always #PTR #34 https://t.co/z2Nct5dIfL",
#   'username': 'MikeLovelace67'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973476804927491,
#   'text': 'to have the @NCAA cause the following happen in order not to have the 2020 season be played in vain... \n\nA. March Madness is renamed MAYhem\nB. The consensus Top 25 Teams play\nC. To take place the week before Memorial Day (May 17-25)',
#   'username': 'ReallyOpenMike'},
#  {'created_at': '2020-03-14 23:41',
#   'id': 1238973450708025349,
#   'text': 'Eau Claire sports bar expecting to take hit after NCAA, NBA cancellations https://t.co/YHRbG26Jav',
#   'username': 'WQOW'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973389106221056,
#   'text': '@CBBonFOX @tsnmike What is preventing this? This can be done over a Thur-Sun time period. No different than a conference tourney. Some venue could easily host this. Not ideal but so is no NCAA tourney altogether. Let’s go!!!',
#   'username': 'MattMattMatt15'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973373897740288,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/yZTFZe7s3C via @Change',
#   'username': 'chiefillfan2'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973321376645120,
#   'text': '@CarlaGalvan7 @Scubadrw @charliekirk11 @NCAA Same',
#   'username': 'cathywolf01'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973282659024897,
#   'text': "@PaulZeise No. They regularly make the NCAA tourney so that is solid. Don't do to well tho. But that can change with a coach like him.",
#   'username': 'PAG162'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973255953735680,
#   'text': '@TheWildcaster @JustinESports The NCAA is absurd to just cancel ..... just think of all the millions CBS paid to show the tourney?......, the NCAA should be forced to give back that $$$$$$$?',
#   'username': 'moffet_russell'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973246638301184,
#   'text': '@stschoberg @marchmadness @NCAA #ThatCouldWork\n\nWelcome back!\nGot out just in time....',
#   'username': 'wack_robert'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973222990872578,
#   'text': '@Lauren_DeFalco Watch ncaa basketball',
#   'username': 'LiveFre72514184'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973216829382656,
#   'text': "@LBaptisia @schmonj @darinp2 @charliekirk11 @NCAA That's racist. I think that's how it works with the left.",
#   'username': 'RickLayneMartin'},
#  {'created_at': '2020-03-14 23:40',
#   'id': 1238973205030875137,
#   'text': '@charliekirk11 @mitchellvii @NCAA Maybe their getting the heck out of there?',
#   'username': 'marlene53292060'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973167252758529,
#   'text': "@SethDavisHoops Seth, Tim Cluess did dominate the MAAC.  Arguably the most successful coach in that league's history.  Pitino will probably put more players in the NBA &amp; potentially advance further in the NCAA Tournament.  But Iona already does dominate the Metro.",
#   'username': 'Kevin_Bruinsma'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973162622193664,
#   'text': "Hey, dumb ass. Compared to deaths in this country from the seasonal flu. Shit. Just because the alphabet soup networks say it is a pandemic, doesn't mean that it is true.\nYou gullible mf's.\nGo along to get along\nNBA, sec, NCAA. Fools, fools. https://t.co/dT56MiFs6w",
#   'username': 'Cmcmurray3'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973160369905667,
#   'text': 'Saturday Edition Subject:\nAmanda Boulier #8 Defense \n*Westminster High School CT\nNew England High School Campion🏆\n*NCAA St. Lawrence University\n150gp 28🚨76🍎=104pts😲\n*1 season Connecticut🐳\n2019 NWHL Defender of the Year Finalist\nIsobel Cup Champion🏆\n3X NWHL ALL⭐️\n📸BJohnson https://t.co/Os95MdztQH',
#   'username': 'MinnesotaCappy'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973150462988289,
#   'text': 'Since we have no sports to watch, and we’ve all been robbed of the best 3 weeks of the year by the NCAA March Madness cancellation (and a likely University of Dayton National Championship), we need @NCAA to consider...',
#   'username': 'ReallyOpenMike'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973133958373376,
#   'text': '@charliekirk11 @mitchellvii @NCAA This is mostly hype so #Trump does not win re-election.',
#   'username': 'georg_dreyman'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973133287313409,
#   'text': 'A little college basketball trivia- who holds the all time NCAA Div 1 record for career scoring?',
#   'username': 'AndreaLeaAOS'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973086499844096,
#   'text': 'Saddest thing about the cancellation of the NCAA tournament:  \n\nKids in a village in Nigeria will not receive their annual shipment of University of Kentucky National Championship t-shirts and hats this year',
#   'username': 'ClosetVol'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973035102834689,
#   'text': 'Welcome to "March Sadness." Affleck\'s movie will have to satisfy our basketball craving. Heck, the way half of the NCAA teams played defense they were never close enough to the opposing players to guard them, much less catch COVID-19!',
#   'username': 'BarryNoble1'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238973000860479489,
#   'text': "@MichaelEHuck @AtticusGF My father has fortunate been very receptive to that and realizes he really does need to stay at home and he's cool with it. Bummed about no sports and not getting to watch the NCAA tournament, but also realizes he's at risk and shouldn't leave.",
#   'username': 'buhhhhlieevmeee'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972989078745089,
#   'text': 'NCAA cancels March Madness amid coronavirus pandemic - CNET: #ai #ml #dl #iot copy: @motorcycletwitt https://t.co/thAombE0Y8 https://t.co/x3hcYk5x5E',
#   'username': 'Social_Molly'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972965146034177,
#   'text': '@GaryParrishCBS Will this hire stand?  GP ...what are the chances Pitino gets hit w a show-cause by NCAA? Wasn\'t Louisville hit w Level 1 "lack of institutional control" under Pitino?',
#   'username': 'jeffrey_jp44'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972963732545545,
#   'text': '@seminole4life22 @DMVCoop301 Thoughts on whether Trent comes back if NCAA grants another year of eligibility?',
#   'username': 'TheRealNole91'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972943797030912,
#   'text': '@_ChristianLowe They might not be played in the same locations, but surely there would be many locations willing to host on short notice 💰. I find it hard to believe the NCAA won’t do everything they can to make money: like  postponing until a later date.',
#   'username': 'TheHammerMcLain'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972939309121538,
#   'text': 'How is the NCAA gonna grant seniors another year of eligibility when there’s another class coming in? Those rosters are going to be huge. I feel horrible for all of the seniors going through this.',
#   'username': 'ashleyhardin12'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972931172110339,
#   'text': "NCAA Offers Blanket Waiver for Athletes' Whose 2020 Spring Season Was Cancelled - https://t.co/OJSYjFHBDJ https://t.co/ZPiHtkCb7k",
#   'username': 'EphSports'},
#  {'created_at': '2020-03-14 23:39',
#   'id': 1238972930220068872,
#   'text': '@Dankha_Gym @flyrodu @danawhite @espn And NCAA, MLB, NBA, NHL, China, Madegascar and the entire country of Italy. What a bunch of sheep, right?',
#   'username': 'SWadleigh'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972870190985217,
#   'text': 'NCAA built tourney safety net of nearly $400M, then spent it https://t.co/ebWMiEdLaY',
#   'username': 'anvil1bighammer'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972861802598401,
#   'text': 'There’s no question that the NBA, MLB, NCAA, MLS and pretty much everyone except the UFC went with common sense, but what does the NFL pushing back free agency do for anyone?',
#   'username': 'LanceTHESPOKEN'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972827585392641,
#   'text': '@buercklin @ReeceStuckey1 @CheerFessions1 Only 1 conference tourney was being played with fans at the time of cancellation and that was the Big East. NCAA doesn’t make money off those tickets sales. That’s 100% MSG’s money. U used a bad example since I’m involved in that sport. 😂😂😂🤡🤡🤡',
#   'username': 'Coach__21'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972818274074624,
#   'text': '@YahooFantasy Any chance to discuss using Yahoo Sports platform for a fundraiser NCAA Pool?  I’d like to create a field, allow folks to create brackets, make a donation, pick ‘winners’, etc.  A little crazy, but looking for fundraising/social distancing activities, etc.',
#   'username': 'BuckyBanker'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972794957938688,
#   'text': '@mknovaa2 People don’t understand. They aren’t champions or been a part of a championship environment. Every high level program kept doing workouts until the NCAA forced a shutdown. M',
#   'username': 'STA_Barstool'},
#  {'created_at': '2020-03-14 23:38',
#   'id': 1238972791585738752,
#   'text': '@DickieV @NCAA N-O',
#   'username': 'DTemp11'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972672224174081,
#   'text': "#MissingMarchMadness  Relive Valpo's miraculous upset victory in the NCAA tournament https://t.co/RqdLIINreO",
#   'username': 'ENord56'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972617597628418,
#   'text': '@BarstoolAlabama Hard to pick one moment, but how about the 4:00 mark where James McFarland sets the NCAA record for shortest return of a pick-six: zero yards.\n(The landshark afterward is just gravy.)\n#GoFrogs\n\nhttps://t.co/3fsxq0kLHW',
#   'username': 'tcudoug'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972595330056192,
#   'text': 'I just figured out how to get 2019 players on NCAA 14. I have never been this happy in my life. https://t.co/UXc4ZIet7T',
#   'username': 'JoshParcell'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972593153044480,
#   'text': 'Just back from Omaha, where every spring event was cancelled. From Cher concert to Berkshire Hathaway meeting,  NCAA, Big East basketball to College World Series. June Olympic Swim Trials at risk. Friday night, I had dinner out and went to a comedy club.',
#   'username': 'SusanneTrimbath'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972589818687493,
#   'text': '@ncaa @marchmadness give them one more shot https://t.co/H1Ko5g7bYf',
#   'username': 'danchim25'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972579039170560,
#   'text': 'The ATPM/Butch and Sundance doubleheader is my NCAA tournament https://t.co/PllQAMKkRH',
#   'username': 'MichaelWeinreb'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972577210654726,
#   'text': 'So I think the @NCAA should send this to all spring and winter sports teams. Also check up on their athletes and coaches because it’s been 3 days and Idk what to do with myself. Supposed to have two games today and instead I sat at home. #redshirtcoronayear https://t.co/ERcdtrxb8O',
#   'username': 'Ktbaby45'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972541881978880,
#   'text': 'NOW IS THE TIME to get Recruited!! The NCAA\'s "Ban" on &amp; off campus recruiting didn\'t stop SLR Recruiting. College coaches can still communicate with recruits! Our PROVEN system is THE answer. Hours later one of our 2021 recruits was offered a FULL ride. Get signed up NOW! https://t.co/UxmXsnEOvx',
#   'username': 'SL_Recruiting'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972493454442497,
#   'text': "@PatWaer25 Having watched every single player on your lineup Pat. Brant Brown would be the best #9 Left handed hitter in the NCAA, I'D SAY. Lance it 30 plus Homer's and some were still rising as they reached the scoreboard @FresnoStateBSB \nWith no sports to watch this is fun @P356Loeffler",
#   'username': 'loren_werth'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972463591145473,
#   'text': '@ChrisAbaray I’m worried about ncaa live periods that’s it',
#   'username': 'Chef_Warzu'},
#  {'created_at': '2020-03-14 23:37',
#   'id': 1238972461397442563,
#   'text': '“To not have that sporting aspect is really making me and other Rowdies feel pretty lost as to what to do in our spare time.”\nTo read more about how some fans felt following the NCAA’s decision to cancel winter and spring sport championships,  click below. https://t.co/LMeWSsMZrk',
#   'username': 'unofficialchris'},
#  {'created_at': '2020-03-14 23:36',
#   'id': 1238972365163376641,
#   'text': 'What’s a captain to do without NCAA Basketball?  Get the boat ready quicker!  New Isinglass installed Friday and bottom paint competed today.  New electronics and a good buffing next week.   We are almost ready for… https://t.co/5LZya1vT7m',
#   'username': 'UnsaltedOutfitr'},
#  {'created_at': '2020-03-14 23:36',
#   'id': 1238972343034081281,
# ...
#   'username': 'jonathan54_'},
#  {'created_at': '2020-03-14 21:55',
#   'id': 1238946922351771649,
#   'text': '@vaughtsviews @wildcatnews @espnVshow Finished 28-5 losing to Georgetown in the 2nd round of the NCAA.\nLosses were UK, San Francisco, Georgetown (twice) and Pittsburgh.\nThey beat Louisville (maybe you recall that one) at Madison Square Garden 77-60 in February.',
#   'username': 'JuryReporter'},
#  {'created_at': '2020-03-14 21:55',
#   'id': 1238946871843811333,
#   'text': "@burg_us @bignizo @JayBilas @NCAA He's a commentator on the games.  Anything else is an activist.",
#   'username': 'TheCincyBuckeye'},
#  {'created_at': '2020-03-14 21:55',
#   'id': 1238946795943854082,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/TMKTfrhMxw via @Change',
#   'username': 'JohnnyGarciaSTL'},
#  {'created_at': '2020-03-14 21:55',
#   'id': 1238946792215130116,
#   'text': 'Iona winner of 2022 NIT Tourney\n#15 Seed in 2023 NCAA Tourney\n#11 Seed in 2024 NCAA Tourney (Sweet 16) https://t.co/ro2nUvzd4G',
#   'username': 'gporter812'},
#  {'created_at': '2020-03-14 21:55',
#   'id': 1238946771939856386,
#   'text': "1981 NCAA St Joseph's upsets top seed DePaul 49-48 #DMZOTDIH https://t.co/PerW6GrgaI #DMZComment",
#   'username': 'DMZ_Online'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946743808602119,
#   'text': 'Someone, with more time than talent than myself, should be writing fictional articles of the scheduled sporting events that should happened but were cancelled. Including NCAA conference and national tourney.',
#   'username': 'jvickers78'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946743733096449,
#   'text': '@ByPatForde You mean from the same NCAA who did nothing to  schools like KU where coaches were wire tapped talking about paying players?  Or is this a different ncaa?',
#   'username': 'Schmidtburgh'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946731997442050,
#   'text': "This has been one of the most stressful weeks that I can remember and I'm not even a collegiate athlete. \n\nHere are a few thoughts on how the recent COVID-19 cancellations and extended spring eligibility could impact the NCAA running community... https://t.co/lErsD2xphF",
#   'username': 'ZatlinBlueArc'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946713202601984,
#   'text': '@charliekirk11 @NCAA It’s a fucking hoax!',
#   'username': 'rscigs'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946692260671488,
#   'text': 'Dear @NCAA If you think we can’t postpone the March Madness because of a month off between competitions, I would refer you to the Bowl Season. Football does it every fall. It can be done.',
#   'username': 'HoopsRadio'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946674334105601,
#   'text': 'PSA: Due to the current COVID-19 situation, the NCAA has mandated a “Dead Period”. https://t.co/zJcPU406JW',
#   'username': 'rhodywsoc'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946639965908993,
#   'text': 'New Episode of A Cup of Joe with UTSA Pitcher Palmer Wenzel! We talk Coronavirus and how it affects the NCAA https://t.co/Z7ghrLxXTd',
#   'username': 'rBirdsUp'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946633322242049,
#   'text': '@Cdean0508 @BCarter03458594 @FunnyMaine We are are all grinning about you thinking the Pentagon panics.  And the CDC, the WHO, the NCAA, NBA, MLB and all the colleges and schools. But carry on.',
#   'username': 'bamamemphis'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946624337924097,
#   'text': '@charliekirk11 @SidneyPowell1 @NCAA Long Easter vacations🤔',
#   'username': 'DearieGerry'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946535859200000,
#   'text': '@charliekirk11 @SidneyPowell1 @NCAA It’s not. Sadly, political crossfire is making many think there’s nothing to worry about.',
#   'username': 'DocOlds2'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946518708695043,
#   'text': '@charliekirk11 @NCAA Just doesn’t make sense',
#   'username': 'Stevemc86104300'},
#  {'created_at': '2020-03-14 21:54',
#   'id': 1238946511620313097,
#   'text': '@charliekirk11 @SidneyPowell1 @NCAA Chill Charlie  they are wanting to go home now.\nJust pray over them and be done with it!',
#   'username': '14Fowl'},
#  {'created_at': '2020-03-14 21:53',
#   'id': 1238946501583425536,
#   'text': '@RochieWBZ @NCAA Right so college gets another full year of tuition for 1 more spring season.  My son is happy about it. I hope he’s paying.',
#   'username': 'aspirito44'},
#  {'created_at': '2020-03-14 21:53',
#   'id': 1238946463079686145,
#   'text': '@WolverineCorner I’m really surprised you don’t remember sitting on your couch and taking in the NCAA Championship when you were 2. 😂',
#   'username': 'wolverine_info'},
#  {'created_at': '2020-03-14 21:53',
#   'id': 1238946461095727104,
#   'text': '@UWBadgers @Badgersmbb No ncaa sucks but still a great season..congrats to the big 10 champs and coach of the year Greg Gard!!#onwisconsin',
#   'username': 'StagmanCarl'},
#  {'created_at': '2020-03-14 21:53',
#   'id': 1238946266823999488,
#   'text': "@RobParkerFS1 @ionacollege If the NCAA says he can coach, then he can coach. There's also much more deplorable crimes across sports in my opinion. That said make sure you stock up on wings and sweet baby Ray's it's getting crazy out there.",
#   'username': 'MarcBrown6986'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946250902257664,
#   'text': '@twitcathe @charliekirk11 @tpixi @NCAA Are the prices lower? I haven’t seen it.',
#   'username': 'denise_artist'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946159076560901,
#   'text': 'Somebody would’ve told me a year ago that Kobe would be dead and the NBA and NCAA would be canceled I would tell them to go get drug tested lol',
#   'username': 'ron_trapps'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946101732036608,
#   'text': 'NCAA update! https://t.co/5WKCzTZsTQ',
#   'username': 'atxskylinejrs'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946097881628672,
#   'text': '@BallerRogue @SactoMan81 @SportsCenter @Trevor_Luznak @NCAA @NBA @FIBA I was thinking that too.  Could it be double dribble or travel (passing to self) but maybe the ball being still eliminates those?',
#   'username': 'KevinParsley75'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946069398118401,
#   'text': '@charliekirk11 @SidneyPowell1 @NCAA https://t.co/rdauK1wgb7',
#   'username': 'dittos88'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946051387584513,
#   'text': '@JonRothstein NCAA to launch immediate investigation into Iona Men’s Basketball program.',
#   'username': 'HurleyFace'},
#  {'created_at': '2020-03-14 21:52',
#   'id': 1238946036133048321,
#   'text': 'College athletes, including golfers, who learned the sobering news on Thursday that all NCAA championships for the remainder of the 2019-’20 season had been canceled as a measure to try to stop the spread of the COVID-19 virus, got some solace on Friday. https://t.co/nrPajIjUOG',
#   'username': 'GolfConnecting'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945956890054658,
#   'text': '@CPyles8 As soon as the US gets the all clear give the NCAA qualifiers 30 days to get weight rt and training in. Wrestle here',
#   'username': 'hundo41'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945949357166592,
#   'text': '@charliekirk11 @NCAA Why are you so stupid.',
#   'username': 'giggsies'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945931627724805,
#   'text': '@realDonaldTrump Thats good mister @realDonaldTrump got cov19 its sure  cause he dont tweet and @realDonaldTrump he\'s like the best  fake président he\'s like ncaa  player  \nA président\'s rookies \n"No its little gripe  " now you got a grip  from your enemies',
#   'username': 'WhiteFlacko92'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945918721941506,
#   'text': '@J461Xo @charliekirk11 @PaulGavigan4 @NCAA I said this earlier this month. My symptoms I had were the same as described. https://t.co/E2XJMan3OJ',
#   'username': 'RickHakes'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945895166681088,
#   'text': "I'm never going to let FSU fans forget that alumni decided to declare themselves NCAA tournament winners in the middle of a pandemic because their school has never managed to win it on the court.",
#   'username': 'KEBrightbill'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945893828759554,
#   'text': "Column: Iona hires Rick Pitino. Surely the school did due diligence on the NCAA Notice of Allegations bomb soon to be dropped on Louisville, the one that will have Pitino's name all over it ... right? https://t.co/GaUOXNkgbd",
#   'username': 'ByPatForde'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945879786024960,
#   'text': 'No fans allowed NCAA games amid coronavirus concerns: League president https://t.co/V9fcCZOTFH via @YouTube',
#   'username': 'VIKBataille'},
#  {'created_at': '2020-03-14 21:51',
#   'id': 1238945816431063040,
#   'text': '@charliekirk11 @SidneyPowell1 @NCAA Denver?',
#   'username': 'redco2012'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945709652664320,
#   'text': 'Abolish the NCAA. Oh wow the Tomahawk Chop.',
#   'username': 'cowhitchurchbot'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945702090133504,
#   'text': '@charliekirk11 @NCAA That’s DIA and that area gets jammed when the train is running slow. Normal for normal times.',
#   'username': 'bhorgs1'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945679319367683,
#   'text': "@e4419 @RDeanWriter @DLLinCLT @HensleyWriter @bo_mcm @GavinColton @browneallover @oparkero I'm making NCAA parallels. Is @McDonalds UCLA? Long-time dynasty. @ChickfilA is Duke? Recent dynasty, squeaky clean. @Wendys is UK? Another classic dynasty. And @longjohnslvrs is like UNLV? Some crazy s%$* that had a big moment in the past but you haven't thought of it in years.",
#   'username': 'DavidBellNovels'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945634272632833,
#   'text': "‼️INTERVIEW ALERT‼️\n@SFCBL_Official President @vincefarfaglia  \n\n-Coronavirus Reaction \n-NCAA suspend or cancel?\n-Extra year of eligibility doesn't solve every problem  \n-what the league is doing to help players whose seasons were cut short\n\nhttps://t.co/jd5c1pmcH8",
#   'username': 'TEA_SportsTalk'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945618816634883,
#   'text': '@JonRothstein Iona immediately under NCAA investigation 😂',
#   'username': 'darringray'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945547135975424,
#   'text': '@Coach_Hamlin So made NCAA last year. Looked like this year did not go as well',
#   'username': 'vaughtsviews'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945517444517891,
#   'text': 'Hey @ncaa I got a lot of eggs for your face',
#   'username': 'TOPHpicks'},
#  {'created_at': '2020-03-14 21:50',
#   'id': 1238945511589191688,
#   'text': 'Hogs improve to 23-12 and will attempt to be the first team to win five games in five days and secure the SEC’s automatic berth in the NCAA Tournament. Jones finishes with 22, Joe with 19 and Whitt with 12.',
#   'username': 'razorigami'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945489283760128,
#   'text': 'Can CBS/ESPN air last year’s NCAA tournaments (Women’s and Men’s) in its entirety for us to watch right now since we’re supposed to be staying inside and we can’t play? I need some sports relief! @CBS @espn',
#   'username': 'Coachsim'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945479481794562,
#   'text': 'Check out my YouTube Video:        Top 10 Prospects 2020 Draft  w/ Highlights\nhttps://t.co/atbqPJtMYx  #MockDraft #Draft #NFL #NCAA @McShay13  @pjmachado @BengalDesigns',
#   'username': 'scottnance04'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945421977935875,
#   'text': 'Since we can no longer pick NCAA brackets, I’m selecting 64 married couples to see whose marriage will NOT survive the quarantine period. Feeling like we are the Duke of my bracket. #COVIDー19 #coronavirus #Day2 #BracketChallenge #ThisIsNuts',
#   'username': 'ljanosko'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945406127611904,
#   'text': "With the Florida Senate deciding to unilaterally declare FSU the NCAA basketball champions, I feel like it's my public duty to remind everyone that unlike FSU, UF actually won the big dance for real. Twice. #GoGators",
#   'username': 'KEBrightbill'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945391674081280,
#   'text': '@CleatEliteAnfro @NCAA The thought that you compare the military academies to state higher learning schools is ignorant',
#   'username': 'bignizo'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945373730856962,
#   'text': 'It would be a huge lie, if I said Saturday’s without sports was fun! \n\n🖕🏼@NCAA @NHL @MLB @NASCAR',
#   'username': 'KevLRNE'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945347218608128,
#   'text': 'Division I just became a bit more interesting in NY with Rick Pitino now head coach at Iona. Let the recruiting wars begin. #NCAA',
#   'username': 'csbanterPFB'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945205237186560,
#   'text': "@Turtle_BITW I was born in 84 what happend in 80 though because on Wikipedia after trying to do research on Coach's new team.  It showed that the 1980 NCAA appearance was vacated for Iona?",
#   'username': 'DapperDandyKy16'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945200782835715,
#   'text': 'I’m awfully lonely. @NCAA @marchmadness @espn @TheAndyKatz @kenpomeroy @ESPNLunardi https://t.co/W3O0Nv5mqa',
#   'username': 'Final4GameBall'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945192859914243,
#   'text': 'NCAA: Let NCAA Athletes Get a Year of Eligibility Back - Sign the Petition! https://t.co/oVld9L22Mz via @Change',
#   'username': 'Jandres791'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945188736831488,
#   'text': '«Καυστικός» ήταν ο Ντιλέινι στο άκουσμα της επιστροφής του Πιτίνο στο NCAA.https://t.co/y9oq5VxKBh',
#   'username': 'gazzetta_gr'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945123360215041,
#   'text': '@UKCoachCalipari Sad, the NCAA took action on this before the President. They’re never on the cutting edge of anything.',
#   'username': 'adamembry'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945117039464450,
#   'text': '@VUHawkTalk @NMStateWGolf @NCAA ABSOLUTELY',
#   'username': 'RealBobbyEarle'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945114002784262,
#   'text': '@CleatEliteAnfro @NCAA Now your saying bama can sign a player for playing football for a total of 12 yrs geez man you are crazy stupid hating on ncaa',
#   'username': 'bignizo'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945016783032320,
#   'text': "@jhammons14 The NCAA NBA MLB all sporting events. Will regret and feel stupid. Once this passes. They could have continued business as usual I'm telling you right now.",
#   'username': 'NATE__USA'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945015558295553,
#   'text': "@UVMmbb @EM_D20 Wait, I fell asleep, woke up and I missed that UVM men's bb won the first three rounds of The NCAA championship? Next game against Gonzaga for a slot in the final four!\nU-V-M .",
#   'username': 'VTJoe99'},
#  {'created_at': '2020-03-14 21:48',
#   'id': 1238945013465300993,
#   'text': '@charliekirk11 @NCAA I normally agree with you, but your obsession with sports is a non starter in this environment. There are worse things than not watching sports.',
#   'username': 'ElfyGanas'},
#  {'created_at': '2020-03-14 21:47',
#   'id': 1238944978681954305,
#   'text': '@makalarch @JonRothstein Or the NCAA investigators',
#   'username': 'clarryellis'},
#  {'created_at': '2020-03-14 21:47',
#   'id': 1238944870024318977,
#   'text': 'Good on the NCAA for extending eligibility',
#   'username': 'eth_savage'},
#  {'created_at': '2020-03-14 21:47',
#   'id': 1238944851560980481,
#   'text': '@DickieV @TooleyDon @Rick_Pitino @IonaGaelsMBB @NCAA Your need to defend this guy is baffling. Roll out the escorts, gaels will be final 4 bound!',
#   'username': 'lynch258'}]

# %%
ncaa_data2 = json.load(open('data/ncaa/#ncaa_2020-03-08_to_2020-03-15.json'))

# %%
ncaa_data2
# Out:
# [{'created_at': '2020-03-14 23:57',
#   'id': 1238977595221454848,
#   'text': 'https://t.co/lnXUzhVIGV #NCAA',
#   'username': 'raiderway83'},
#  {'created_at': '2020-03-14 23:54',
#   'id': 1238976931699347467,
#   'text': 'Since everyone is quarantined and no #ncaa or #nba...the #ps4 server is dead ass like: https://t.co/2zIHErEGWY',
#   'username': 'His_Majesty_J'},
#  {'created_at': '2020-03-14 23:50',
#   'id': 1238975774197194761,
#   'text': 'May Madness would be great! #MarchSadness2020 #NCAA #NCAATournament',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:45',
#   'id': 1238974636911722496,
#   'text': 'There is no way the CFP would have been cancelled #omaha #COVIDー19  #ncaa',
#   'username': 'KennyLedford21'},
#  {'created_at': '2020-03-14 23:42',
#   'id': 1238973909732659200,
#   'text': 'To hockey to wrestling and all the other winter sports. Competing for a National Championship is an ultimate dream for many. Maybe the NCAA can re-evaluate their decision? April Madness or May Madness would be great! #NCAATournament #MarchSadness2020 #NCAA',
#   'username': 'JKarpo20'},
#  {'created_at': '2020-03-14 23:32',
#   'id': 1238971411630379013,
#   'text': "By the way, we're the national champions. #RockChalk @KUHoops @KUAthletics #KUPride #NCAA #NCAATournament https://t.co/UFxS7KY6sD",
#   'username': 'pandaflamethrow'},
#  {'created_at': '2020-03-14 23:29',
#   'id': 1238970643665891328,
#   'text': '#ncaa \n#recruit https://t.co/M554Yrh4BW',
#   'username': 'HaringeyHawks'},
#  {'created_at': '2020-03-14 23:28',
#   'id': 1238970240504967169,
#   'text': 'Rick Pitino #NBA #NCAA Coach \nVintage Collectible\n1987-88 NY Knicks Media Guide\nhttps://t.co/RGHbhS5EYK',
#   'username': 'JIMMURRAYSPORTS'},
#  {'created_at': '2020-03-14 23:28',
#   'id': 1238970240014450689,
#   'text': '#OffSeason #track #Training with my brother. #Coronavirus tests your commitment.\n\n #ClassOf2022 #WGCSWarriors #NCGoldBears #JrCheckersAAA \n\n#Hockey #NCAA #StudentAthlete #College #NCAAHockey #CollegeSports #Team https://t.co/G3kDYQcAEW',
#   'username': 'pucksammich'},
#  {'created_at': '2020-03-14 23:20',
#   'id': 1238968221539147778,
#   'text': '#NCAA Rick Pitino is returning to college basketball as Iona coach https://t.co/s0TiXEdwoP',
#   'username': 'MauricioAndrsL6'},
#  {'created_at': '2020-03-14 23:18',
#   'id': 1238967682038468613,
#   'text': 'My prediction of a Champion for this year’s NCAA Tourney... Sad but true.... #MarchMadness #NCAATournament #COVIDー19 #ncaa https://t.co/1UMP2V251Z',
#   'username': 'PKScratch'},
#  {'created_at': '2020-03-14 23:16',
#   'id': 1238967325300318210,
#   'text': 'Hypothetical 16-team #NCAA Tournament (24 hours per round)\n\nVote in thread!!!\n\nSeed list: \n1. Kansas\n2. Gonzaga\n3. Baylor\n4. Dayton\n5. FSU\n6. SDSU\n7. Duke\n8. Villanova\n9. Kentucky\n10. MSU\n11. Creighton\n12. UMD\n13. SHU\n14. UL\n15. Oregon\n16. Wisconsin',
#   'username': 'rheidrick24'},
#  {'created_at': '2020-03-14 23:14',
#   'id': 1238966856658161666,
#   'text': '@IonaGaelsMBB will be National Contenders in no time......If they ever play college basketball again #NCAATournament #NCAA',
#   'username': 'MAbramsboxing'},
#  {'created_at': '2020-03-14 23:12',
#   'id': 1238966309582299136,
#   'text': 'Just $14- NEW University Of #Arizona Official Licensed Flag U OF A 3’x5’ Outdoor w Grommets #UofA #UniversityOfArizona #college #ncaa \nhttps://t.co/2bzGUCmOZ1 @eBay',
#   'username': 'UrbanScootsEbay'},
#  {'created_at': '2020-03-14 23:11',
#   'id': 1238965917322817536,
#   'text': "Screw #MarchMadness, I want to see Ellen DeGeneres vs. Rosie O'Donnell in the Battle for Bruce Jenner's pecker\n\n#coronavirus #COVIDー19 #COVID19 #CoronaVirusUpdate #NCAA #Basketball #Funny #Joke #Virus #Trump #coronapocolypse #CoronaOutbreak #CoronavirusPandemic",
#   'username': 'OscarMoore4USA'},
#  {'created_at': '2020-03-14 23:10',
#   'id': 1238965769871867904,
#   'text': '“‘That’d be a tough sell to your wife to say: ‘Honey, you need to use birth control for another year. I’m postponing my vasectomy for another year for the next #NCAA tournament.’” https://t.co/ahwXa0fyqq \n\nby @jacobbogage \n\n#coronavirus #MarchMadness',
#   'username': 'West_Syed'},
#  {'created_at': '2020-03-14 23:01',
#   'id': 1238963377084473346,
#   'text': '3/11/20 Pac-12 Tourney: #3 Stanford Cardinal beat #2 UCLA Bruins 67-51 in the Semifinals. Click on the link below for more photos from this game.\n#Pac12TournamentWBB #UCLABruins #StanfordCardinal #Pac12 #NCAA #TGSportstv1\nhttps://t.co/uWQdPkntvY https://t.co/xPzUjKbeAU',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 22:58',
#   'id': 1238962761117265920,
#   'text': '🏀ECC rundown via that @MWhicker03LANG ? 🤔 \n#NCAA Street and Smith Basketball 1982 https://t.co/QyR663CEyS',
#   'username': 'NotesnaScorcard'},
#  {'created_at': '2020-03-14 22:56',
#   'id': 1238962203656704000,
#   'text': 'Welcome back @RealPitino to US hoops. It means 2 things @IonaGaelsMBB will return to the #NCAATourney is quick measure and the #NCAA will match them against either @KentuckyMBB or @LouisvilleMBB in the opening weekend',
#   'username': 'KennyRiceSports'},
#  {'created_at': '2020-03-14 22:55',
#   'id': 1238961914857865224,
#   'text': "So who are we crowning as the champ of men's #NCAA hoops 🏀?\n\nHighest (subjectively-rated) team? @KUHoops \nTeam with the best record? @Aztec_MBB \nOr how bout BEST TEAM IN THE BEST CONFERENCE!? @BadgerMBB https://t.co/fNJWAzdnV4",
#   'username': 'RobLauer'},
#  {'created_at': '2020-03-14 22:55',
#   'id': 1238961903340326917,
#   'text': 'Wow I miss basketball..#NBA #NCAA',
#   'username': 'BrandonPerraul1'},
#  {'created_at': '2020-03-14 22:54',
#   'id': 1238961845916110849,
#   'text': '#RickPitino #NCAA🏀 #Iona\n\nhttps://t.co/3M4GoEhRhy',
#   'username': 'He3Man7'},
#  {'created_at': '2020-03-14 22:54',
#   'id': 1238961783311826945,
#   'text': 'Since the #NCAA awarded an extra year of eligibility (which was the right thing do), that means all rosters will have 20% more players for a few years. Are they also increasing the roster and scholarship limits by 20%?',
#   'username': 'LanceDearborn'},
#  {'created_at': '2020-03-14 22:51',
#   'id': 1238961024881098755,
#   'text': 'Updates on recruiting from the #ncaa https://t.co/DbEKPvKO8N',
#   'username': 'GoNUwsoccer'},
#  {'created_at': '2020-03-14 22:48',
#   'id': 1238960314898669568,
#   'text': 'You guys... if you think about it “March Madness” never really got canceled.\n#COVIDー19 #NCAA',
#   'username': 'Aray2Go'},
#  {'created_at': '2020-03-14 22:47',
#   'id': 1238960072635678722,
#   'text': 'They forgot the @HorizonLeague Champs\n\n#NorseUp #HLMBB #TakeNotice #REACHtheHORIZON #MarchMadness #NCAA @NKUNorse @NKUalumni @nkuedu @northernersport @NKUNorseMBB https://t.co/gU0u200Aeb',
#   'username': 'CincyFanZone'},
#  {'created_at': '2020-03-14 22:47',
#   'id': 1238959986706993154,
#   'text': '1. I think a few other teams might have something to say about this.\n\n2. Really, #Florida Senate? You don’t have anything better to do than try crowning one of your state’s teams as the #NCAA champion? \n\n#MarchMadness #NCAAMBB https://t.co/KmmD8PI127',
#   'username': 'Heath_Lewis'},
#  {'created_at': '2020-03-14 22:46',
#   'id': 1238959598540750848,
#   'text': '"#SportsNews: #NCAA plans to extend eligibility of spring sports athletes - Bloomington Pantagraph #News": https://t.co/peoB6OZBMm',
#   'username': 'robinsnewswire'},
#  {'created_at': '2020-03-14 22:38',
#   'id': 1238957593856544768,
#   'text': '@aleman009 Diache, porque tampoco me voy a pasar el tiempo leyendo, me siento vacía. \nYo esperando esa locura de marzo de la #NCAA',
#   'username': 'RoaMarta2'},
#  {'created_at': '2020-03-14 22:37',
#   'id': 1238957434745401344,
#   'text': '#Florida senate officially declares Florida State national champions amid coronavirus pandemic... #FloridaSucks #NCAA #CoronaVirus #basketball  https://t.co/veX18ZU22M',
#   'username': 'EvilDevilInside'},
#  {'created_at': '2020-03-14 22:37',
#   'id': 1238957382228758529,
#   'text': 'We’ve had a lot of big announcements this week. Cancellations, delays, added eligibility - there’s a lot to process\nWondering what this all means? \u2063\nBe sure to check out @jm3sports latest blog for thoughts on the #NCAA news and what it means for current and future NCAA players🎯 https://t.co/DImn4NpWc1',
#   'username': 'CentralLaxMA'},
#  {'created_at': '2020-03-14 22:35',
#   'id': 1238957010827087872,
#   'text': '3/6/20 Pac-12 Tourney: #3 Stanford Cardinal beat #6 Oregon State Beavers 68-57 in the first round. Click on the link below for more photos from this game.\n#Pac12TournamentWbb #StanfordCardinal #NCAA #OregonStateBeavers #TGSportstv1\nhttps://t.co/ftwPndLoDo https://t.co/7vyDEvlyyK',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 22:25',
#   'id': 1238954400686587904,
#   'text': 'How people are watching ESPN after every other sport has been cancelled.. \n\n@SupremeDreams_1 #nba #nhl #mls #usl #pga #xfl #ncaa https://t.co/mXIFEZKUyp',
#   'username': 'KleverShirtz'},
#  {'created_at': '2020-03-14 22:24',
#   'id': 1238954227302420480,
#   'text': 'For #Portland_Pilots women’s basketball, euphoria is fleeting as #NCAA Tournament is canceled https://t.co/732SdniZDp',
#   'username': 'carol_sundahl'},
#  {'created_at': '2020-03-14 22:24',
#   'id': 1238954172038275073,
#   'text': '🏀Top High School Hoops profiles via Dave Krider. 78-79 Street and Smith featuring @JamesWorthy42 @ClarkKelloggCBS @DWilkins21 not "Wilkens" Ralph, Isaiah, Sam Bowie.... @Super70sSports @mattmoneysmith @LakersNation @LakersSBN @ProHoopsHistory #NBA #NCAA https://t.co/nyuR8JJG0u',
#   'username': 'NotesnaScorcard'},
#  {'created_at': '2020-03-14 22:24',
#   'id': 1238954072604057601,
#   'text': 'and just like that...our season has been abruptly taken from us. It still doesn’t feel real...we WILL be back next year stronger than ever and we WILL be turning heads. AU Women’s Lacrosse’s story is far from over #finishunforgettable #NCAA https://t.co/x4LrHBTg1B',
#   'username': 'LindseyBateman1'},
#  {'created_at': '2020-03-14 22:21',
#   'id': 1238953479101657090,
#   'text': 'Former #Louisville coach #RickPitino returns to college basketball, hired to be next coach at #Iona: https://t.co/CrkEmMcKxk\n#NCAA\n#NCAABasketball',
#   'username': 'kevintmcevoy'},
#  {'created_at': '2020-03-14 22:20',
#   'id': 1238953293348511744,
#   'text': 'I used a simulator to go through what the NCAA Tournament might have looked like. Comment below how you think the tournament would have gone! ⬇️👀 #NCAA #MarchMadness #MarchSadness #ncaabasketball https://t.co/UMSboMjKRd',
#   'username': 'itsjustsports3'},
#  {'created_at': '2020-03-14 22:16',
#   'id': 1238952106842828804,
#   'text': 'Get the help you need for the transition to online courses. Call @RayswritingS to get stuff done in these trying times.\n\n#College #Essay #Graduate #APA #MLA #Dissertation #Thesis #Major #University #Grade #EssayHelp #Papers #Help #Graduation #Time #Prompt #Deadline #Goals #NCAA https://t.co/Ie8DBdOZby',
#   'username': 'RayswritingS'},
#  {'created_at': '2020-03-14 22:15',
#   'id': 1238952000789905419,
#   'text': 'Heading to Atlanta for the Final Four matches. #ncaa #basketball #great @ Carnegie Hill https://t.co/BJmVmXSk55',
#   'username': 'connorarose'},
#  {'created_at': '2020-03-14 22:14',
#   'id': 1238951724049563649,
#   'text': '🏀 #NCAA /#NBA preview circa 1978 via Street and Smith Basketball. \nMidwest Preview via @woodypaige @Super70sSports https://t.co/cFU1mvTsO0',
#   'username': 'NotesnaScorcard'},
#  {'created_at': '2020-03-14 22:12',
#   'id': 1238951076990050304,
#   'text': '3/6/20 Pac-12 Tourney: #2 UCLA Bruins knock off #7 USC Trojans in the first round. Click on the link below for more photos from this game.\n#Pac12TournamentWbb #UCLABruins #USCTrojans #NCAA #TGSportstv1 #Bruins #Trojans\nhttps://t.co/1xF71sPAg1 https://t.co/aSysEbgbD2',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 22:08',
#   'id': 1238950214586818565,
#   'text': 'Win-Win-Win: @Twitch can you put together a #MarchMadness tournament with @CBS on @NBA2K with one player from 64 college teams, and split $ with orgs supporting folks laid off this month? It’ll do good, provide needed entertainment, and get you new customers. #coronavirus #ncaa',
#   'username': 'mmuench'},
#  {'created_at': '2020-03-14 22:06',
#   'id': 1238949751887998977,
#   'text': 'Congratulations to Michael-Anthony Deslauriers on his NCAA DIII commitment to Northland College! #93HS #NCAA #NCJacks https://t.co/Ki0jBd6Mup',
#   'username': '93HkyServices'},
#  {'created_at': '2020-03-14 22:00',
#   'id': 1238948126758707201,
#   'text': "For the first time since 1939, there will be no men's NCAA basketball tournament. And there won't be a women's NCAA basketball tournament, either. Who would you have picked to win?\n\n#coronavirus #ncaa #championship #basketball #bigdance #finalfour #college #march #washyourhands https://t.co/T3jCm5uTBf",
#   'username': 'IntellectPt'},
#  {'created_at': '2020-03-14 21:56',
#   'id': 1238947052790349827,
#   'text': '@stlsportsmed #NCAA has plenty of teams abusing opioids. Strength coaches paid by delivering PEds with advice to conceal use. Gets to https://t.co/1dVyCauZhN money for research since Hainline and Putukian started selling the pre-x BS/mental illness crap to escape brain damage issue.',
#   'username': 'NFLObjectors'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945479481794562,
#   'text': 'Check out my YouTube Video:        Top 10 Prospects 2020 Draft  w/ Highlights\nhttps://t.co/atbqPJtMYx  #MockDraft #Draft #NFL #NCAA @McShay13  @pjmachado @BengalDesigns',
#   'username': 'scottnance04'},
#  {'created_at': '2020-03-14 21:49',
#   'id': 1238945347218608128,
#   'text': 'Division I just became a bit more interesting in NY with Rick Pitino now head coach at Iona. Let the recruiting wars begin. #NCAA',
#   'username': 'csbanterPFB'},
#  {'created_at': '2020-03-14 21:43',
#   'id': 1238943898547949573,
#   'text': '#NCAA ✍️RESMİ: Pitino, NCAA Takımlarından Iona Koleji ile Anlaştı #Euroleague \nhttps://t.co/w7s8Vyy7UQ',
#   'username': 'fersudeniz'},
#  {'created_at': '2020-03-14 21:41',
#   'id': 1238943444933935106,
#   'text': 'Great governance!! #NCAA\n\nNCAA built safety net of nearly $400 million, then spent it\n\nhttps://t.co/gRi1BOqe1Y',
#   'username': 'Imready4it1'},
#  {'created_at': '2020-03-14 21:40',
#   'id': 1238943162783027200,
#   'text': '🏀S&amp;S WBB All Americans/Top 20 Preview... @KimMulkey @BaylorWBB @AllDecade14 @USCWBB @biancahock #NCAA #WBB https://t.co/dmdR4AW2cw',
#   'username': 'NotesnaScorcard'},
#  {'created_at': '2020-03-14 21:40',
#   'id': 1238943033363697665,
#   'text': 'Bored this weekend? Not going out because of the #coronavirus Why not check out episode 50 of Sports Talk Buffalo\n#Buffalo #UBhornsUP #NCAA \n#Bills #NFL #BillsMafia \n\nhttps://t.co/DLG8RhcP8w',
#   'username': 'Sportstalkbuff1'},
#  {'created_at': '2020-03-14 21:40',
#   'id': 1238943009057710080,
#   'text': 'Spoiler alert...there is no chance the TUC caps attendance at 7K when Iona plays at Siena next year. \n\n#SienaSaints\n#MAACHoops\n#NCAA\n#FeelingStreaky https://t.co/tXwEYoHYpa',
#   'username': 'LastSienaIndian'},
#  {'created_at': '2020-03-14 21:40',
#   'id': 1238942993861599232,
#   'text': '3/11/20 Big West Tourney: #3 UC Irvine Anteaters loss to #8 Cal Poly Mustangs 70-49 in the Quarterfinals. Click on the link below for more photos from this game.\n#BigWestTournament #CalPolyWbb #UCIrvineWBB #NCAA #TGSportstv1\nhttps://t.co/CVUH7d8nvs https://t.co/NVY6hE70TT',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 21:36',
#   'id': 1238942021416636418,
#   'text': '#UT to Shaka, July 2019: "You really need to make the NCAA Tourney in 2020."\nShaka, now: "I didn\'t NOT make the #NCAA Tournament!"',
#   'username': 'MELovins'},
#  {'created_at': '2020-03-14 21:34',
#   'id': 1238941614678192134,
#   'text': 'I’m just going to imagine every mundane activity I do this month is being narrated by Gus Johnson. It’s the only way I feel like I can cope. Getting out of bed in the morning... “and the slipper still fits!” Or cleaning - “Heckard with the Lysol...again. Yes!” #MarchSadness #NCAA',
#   'username': 'JordanHeckard'},
#  {'created_at': '2020-03-14 21:33',
#   'id': 1238941386940059649,
#   'text': "Reaction to #NCAA cancelling #marchmadness \n\nMy podcast, It's Complicated Ep. #007 is available on Spotify and YouTube right now. \n\nThe first 6 episodes are available on all platforms. \n\n#ItsComplicated #coronavirus #COVID19 #COVID #MarchSadness #podcast #KC #KansasCity https://t.co/jsCTsykuGS",
#   'username': 'JakeShirk_ES'},
#  {'created_at': '2020-03-14 21:28',
#   'id': 1238940094674997248,
#   'text': 'One of the greatest #NCAAGym saying her goood bye. Stinks that we couldn’t see her and the rest of the class of 2020 one last time. @MagsGotSwag12 #gymnastics #NCAA https://t.co/ISBVTwOWwz',
#   'username': 'SarahNelson11'},
#  {'created_at': '2020-03-14 21:27',
#   'id': 1238939830144266240,
#   'text': "So good I had to share! Check out all the items I'm loving on @Poshmarkapp from @Dorothy86298952 #poshmark #fashion #style #shopmycloset #adamlevinecollection #sanrio #ncaa: https://t.co/d2HlerwEIZ https://t.co/nYC3hJ3IhJ",
#   'username': 'Bobby02816667'},
#  {'created_at': '2020-03-14 21:26',
#   'id': 1238939526917226496,
#   'text': 'Dear @NCAA, I think giving any college athlete who is a senior in 2020 the opportunity to have another year of eligibility if they feel led to play next year is the right thing to do.  #COVID19 #NCAA',
#   'username': 'calebhawk'},
#  {'created_at': '2020-03-14 21:26',
#   'id': 1238939504603467778,
#   'text': 'The @SEC is still happening everyone.  Then in. @HighDeff14 #NCAA #marchmadness2020 #MarchSadness https://t.co/J4b4dZfiYp',
#   'username': 'BKDizz'},
#  {'created_at': '2020-03-14 21:25',
#   'id': 1238939343265333250,
#   'text': 'Extending eligibility MUST happen for winter AND spring athletes. @NCAA made the call for Spring Sports, but winter athletes depend on tourneys, awards, etc. for their futures. Make it happen #NCAA. https://t.co/e7a0wRPDZa @fastpp3 @LukaG_55 @JordanBo_3 @B1Gcat15 @Bakari_Evelyn11',
#   'username': 'jaymo1978'},
#  {'created_at': '2020-03-14 21:24',
#   'id': 1238939194095013889,
#   'text': '@charliekirk11 @NCAA SOOOOO much worse than allowing the #NCAA tournament. Just ban fans but let them play. It’s a tragedy for the seniors that earned their spot. So sad.',
#   'username': 'TiffanyBakerUS'},
#  {'created_at': '2020-03-14 21:23',
#   'id': 1238938746172723201,
#   'text': '#Grizzlies JA MORANT #297 TRIBUTE 2017-19 #NCAA TOTALS 2019-20 PANINI-HOOPS BASKETBALL #NBA #SportsCards \n\nhttps://t.co/dol4aJYrCn https://t.co/bybsKeqSqk',
#   'username': 'Printspixnremix'},
#  {'created_at': '2020-03-14 21:22',
#   'id': 1238938683245551619,
#   'text': 'My first perfect bracket! #NCAA #coronavirus https://t.co/gXgVixkQWb',
#   'username': 'Mitch4_'},
#  {'created_at': '2020-03-14 21:22',
#   'id': 1238938554153099264,
#   'text': '3/11/20 Pac-12 Tourney: #5 Arizona Wildcats beat #12 Washington Huskies 77-70 in the first round.\n#Pac12 #Pac12Tournament #WashingtonHuskies #NCAA #ArizonaWildcats #TGSportstv1 https://t.co/BtlmfRQak3',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 21:21',
#   'id': 1238938231636406273,
#   'text': 'Rick Pitino è il nuovo coach di IONA College a New York dalla prossima stagione!\n\nLascia il Panathinaikos anche se ha confermato che terminerà la stagione di campionato e #EuroLeague se riprendesse dopo la sospensione.\n\n#NCAA #collegebasketball #pitino https://t.co/KH4s8CZodE',
#   'username': 'Basketcaffe'},
#  {'created_at': '2020-03-14 21:17',
#   'id': 1238937262299152391,
#   'text': '#NCAA | Pues R.Pitino vuelve al College, habrá que ver cómo lo compagina con el tema de Grecia. https://t.co/swlB8R4h66',
#   'username': 'alean11'},
#  {'created_at': '2020-03-14 21:14',
#   'id': 1238936514840625156,
#   'text': 'https://t.co/wktTh0nYXM #NCAA: Rick Pitino returns to college basketball as new #Iona coach https://t.co/PuTdP6gnmh #sports',
#   'username': 'bigdaddycasino'},
#  {'created_at': '2020-03-14 21:12',
#   'id': 1238936128784404483,
#   'text': 'Hope everyone is staying safe and healthy throughout these tough times! Remember health is first! We will be back to getting this money in no time! \n\n-Dr. P\n\n#GamblingTwitter #sports #CollegeBasketball #NCAA #NBA #CoronaVirusUpdates #coronapocalypse',
#   'username': 'DrPicks11'},
#  {'created_at': '2020-03-14 21:11',
#   'id': 1238935893068509184,
#   'text': 'Get scouted... Be recruited! #prepsports #ncaa #naia @ Crescent bar https://t.co/M4zbdPucLZ',
#   'username': 'coach_Liggett'},
#  {'created_at': '2020-03-14 21:09',
#   'id': 1238935316821610496,
#   'text': 'Day 3 of no sports #nfl #vols #ncaa @Vol_Football https://t.co/cd9JlDCoRi',
#   'username': 'kswearin'},
#  {'created_at': '2020-03-14 21:07',
#   'id': 1238934904626388992,
#   'text': 'How much money is the #NCAA losing by not even playing the Championship games?  \n\n#BigTen\n#COVIDー19',
#   'username': 'MyHeartAmerica'},
#  {'created_at': '2020-03-14 21:07',
#   'id': 1238934853120335872,
#   'text': 'Pitino to #Iona?   Finally good news for New Rochelle.  The strippers are coming!  #NCAA',
#   'username': 'robsportstalkfl'},
#  {'created_at': '2020-03-14 21:07',
#   'id': 1238934726150434819,
#   'text': 'So how long until the #NCAA comes calling at Iona? https://t.co/YdLCVGv1Ma',
#   'username': 'jcaakauff'},
#  {'created_at': '2020-03-14 21:06',
#   'id': 1238934528929996809,
#   'text': '📣 New Podcast! "The 3 Point Conversion Sports Lounge- (Should NBA Extend Season), Interview W/ Green Bay Packers Za\'Darius Smith, NFLPA Vote On CBA," on @Spreaker #battlegrounds #coronavirus #giannis #lebronjames #nba #ncaa #nflpa https://t.co/BBiQsMNrtm',
#   'username': '3ptCnvrsn'},
#  {'created_at': '2020-03-14 21:04',
#   'id': 1238933949222551552,
#   'text': '3/11/20 Pac-12 Tourney: #10 California GoldenBears beat #7 Stanford Cardinal 63-51 in the first round. Click on the link below for more photos from this game.\n#Pac12Tournament #CalBears #StanfordCardinal #NCAA #Pac12 #TGSportstv1\nhttps://t.co/pT1gL8ge78 https://t.co/i5oI61X86I',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 21:03',
#   'id': 1238933883741261825,
#   'text': 'DANG IT!!!😡 #NBA #NCAA #SEC https://t.co/sPVMRDD0WM',
#   'username': 'Crissypoo492'},
#  {'created_at': '2020-03-14 21:02',
#   'id': 1238933569554309120,
#   'text': '@MattNorlander @CBSSports All these qualified Black coaches and they pick crook to lead there men instead. Wow!!!!!!!\n#thisisamerica \n#ncaa\n#blackcoaches',
#   'username': 'itsmejsanders'},
#  {'created_at': '2020-03-14 21:02',
#   'id': 1238933548876419074,
#   'text': 'The #BBP Committee is working with our local sources, monitoring the #NCAA and following the #COVIDー19 outbreak. At this point, we expect that there will be Buddy Bowl Pickem in 20/21. Udates will be given as needed. At this time our thoughts and prayers are with those affected.',
#   'username': 'BPickem'},
#  {'created_at': '2020-03-14 21:02',
#   'id': 1238933520015405056,
#   'text': 'Interesting... \n\n#ncaa #ncaabasketball #showmespringfield #BeHuman https://t.co/p5Q57xsbsh',
#   'username': 'NickCarita'},
#  {'created_at': '2020-03-14 21:02',
#   'id': 1238933457834835968,
#   'text': '&amp;#55357;&amp;#56394;  Attention Fans of #NFL #NCAA ...Click here https://t.co/wBKrxSpt2X for #hotsale #fanshop items &amp;#55356;&amp;#57280; &amp;#55356;&amp;#57288; &amp;#9918;&amp;#65039;',
#   'username': 'savabundle'},
#  {'created_at': '2020-03-14 21:00',
#   'id': 1238932988106326016,
#   'text': 'New England Patri... https://t.co/Gf8veSSUHr #nfl #mlb #nba #nhl #ncaa #757sc',
#   'username': '757SC'},
#  {'created_at': '2020-03-14 21:00',
#   'id': 1238932987300978690,
#   'text': "Pretty crazy that I will be a student in the Sports Comm program at @ionacollege when Rick Pitino takes over as head Men's Basketball Coach #Iona #NCAA",
#   'username': 'Allen_Austin_'},
#  {'created_at': '2020-03-14 20:57',
#   'id': 1238932407421722629,
#   'text': 'Was just thinking the same thing. @espn #Chicago #Bulls #cancel2020 #SportsRelief2020 #nba #MLB #ncaa #marchmadness2020 https://t.co/b1wuf1OhSc',
#   'username': '21ctod'},
#  {'created_at': '2020-03-14 20:57',
#   'id': 1238932238156218368,
#   'text': '3/11/20 Pac-12 Tourney: #6 Colorado Buffaloes loss to #11 Washington State Cougars 82-68 in the first round. Click on the link below for more photos from this game.\n#Pac12Tournament #WashingtonStateCougars #NCAA #Pac12 #ColoradoBuffaloes #TGSportstv1\nhttps://t.co/LwoKXajo1W https://t.co/V0XNn8XxoC',
#   'username': 'tgsportsusa'},
#  {'created_at': '2020-03-14 20:56',
#   'id': 1238932111496790017,
#   'text': 'Shouts out to mrbaker80  for the creativity!!!!\n\n@314SportsTalk is about to Bring THAT THUNDER!!!\n\n#MLB #NCAA #NHL #NBA #WWE #STL #xfl #ThePlatformSportsTalkShow #NHL #UFC #BOXING #SPORTS #NFL #ESPN #ESPNFIRSTTAKE… https://t.co/EA1UhHhorm',
#   'username': 'FredakaSmoooth'},
#  {'created_at': '2020-03-14 20:56',
#   'id': 1238932035617591299,
#   'text': 'Damn @pizzahut didn’t have to do me like THAT #CancelEverything #ncaa #MarchSadness #coronamemes https://t.co/gmvoQICiVT',
#   'username': 'JTownTX'},
#  {'created_at': '2020-03-14 20:54',
#   'id': 1238931449610469376,
#   'text': 'Currently airing on @CBSSports... the 2019 @B1GMBBall Championship. A good one from a year ago! #MarchMadness #NCAA @MSU_Basketball @umichbball https://t.co/wEi1AepWGv',
#   'username': 'LyleMultimedia'},
#  {'created_at': '2020-03-14 20:51',
#   'id': 1238930685244723200,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @Azn_b_u_t: Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @thesportgene: RT @BlueCollarMG: Should the #NCAA… https://t.co/9BKiTueENX',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 20:47',
#   'id': 1238929736069414919,
#   'text': 'After being fined for bribery, Rick Pitino will return as an #NCAA Coach for #Iona. \n\nHe last coached #Louisville in 2017. Since then he’s been overseas.',
#   'username': 'hathawaygeorge9'},
#  {'created_at': '2020-03-14 20:46',
#   'id': 1238929611075072007,
#   'text': 'Pitino napustio Grčku, vraća se koledž košarci &gt;&gt; https://t.co/NMPxxVrvQB #rtsvesti #Pitino #Euroleague #NCAA https://t.co/AmKV1m5VXJ',
#   'username': 'RTS_Sport'},
#  {'created_at': '2020-03-14 20:46',
#   'id': 1238929539192913920,
#   'text': 'hey ncaa and gambling world,\nif you guys are cool with rerunning last year’s march madness tournament, i bet i’d do WAY better.\n-thanks #ncaa #MarchMadness #vegas',
#   'username': 'tractorcomedy'},
#  {'created_at': '2020-03-14 20:46',
#   'id': 1238929409085706242,
#   'text': 'I miss sports, it’s only been 3 days 😩. #NBA #MLB #NCAA',
#   'username': 'MarvalisWun'},
#  {'created_at': '2020-03-14 20:45',
#   'id': 1238929273177673728,
#   'text': '🐍🐍🐍🐍🐍🐍 #Iona #RickPitino #NCAA https://t.co/5mNe1ikvO8',
#   'username': 'sneakerboyt'},
#  {'created_at': '2020-03-14 20:45',
#   'id': 1238929212293210112,
#   'text': 'Man, you know what would have been really great to watch this weekend? College basketball 😫 #ncaa #COVIDー19',
#   'username': 'kdinges'},
#  {'created_at': '2020-03-14 20:39',
#   'id': 1238927798229544960,
#   'text': 'Good news #NCAA #basketball recruits: Rick Pitino is heading to @ionacollege.  Head to Iona for the best in bribery, escorts, vacated victories and firing with cause. Iona = basketball’s newest party school. https://t.co/751YG9sxRb',
#   'username': 'AlexDamsker'},
#  {'created_at': '2020-03-14 20:35',
#   'id': 1238926668053516290,
#   'text': "Some colleges care little about morals and common decency.  \n\nCongrats to #Iona, you are the lowest of the low for hiring lowlife Rick Pitino as your head coach.  \n\nOn the bright side, hookers' income should rise in the New Rochelle area.\n\n#NCAA https://t.co/YD0c5JXJM9",
#   'username': 'ROpinion'},
#  {'created_at': '2020-03-14 20:31',
#   'id': 1238925713970954241,
#   'text': '#GamblingTwitter #MarchMadness #NCAA https://t.co/OtrI1SQ8ms',
#   'username': 'PaKalivoda'},
#  {'created_at': '2020-03-14 20:29',
#   'id': 1238925363583111179,
#   'text': 'According to @espn , PITINO is over from Panathinaikos! Iona (NCAA College Team) has also welcomed him with special post on Twitter..💣🔥 #panathinaikos #paobc #rickpitino #ncaa #HallOfFame #basketball https://t.co/VKYG4H5bC3',
#   'username': 'greenclubnews'},
#  {'created_at': '2020-03-14 20:29',
#   'id': 1238925132459995136,
#   'text': '@RexChapman Since the #NCAA sports year is over, it appears they unveiled  @byu_cosmo early. Glad to see he is keeping himself busy during the hiatus #BYU #GoCougs',
#   'username': 'BillHerlin'},
#  {'created_at': '2020-03-14 20:27',
#   'id': 1238924634428444673,
#   'text': 'Rick Pitino the new head Basketball coach at @IonaGaelsMBB. At least something exciting happened in sports today.  #GoGaels #Iona #ncaa #basketball',
#   'username': 'MikeGrella'},
#  {'created_at': '2020-03-14 20:25',
#   'id': 1238924222640132096,
#   'text': 'Ready for #NCAA football 2021!!!! #COVID19 https://t.co/CaMxQGoNn8',
#   'username': 'mikeward2525'},
#  {'created_at': '2020-03-14 20:24',
#   'id': 1238924051457900544,
#   'text': '#atlsportsbar\n\n#jimmizetv\n\n#coacho on #COVIDー19 \n\n#lsu\n\n#SEC \n\n#NCAA \n\n#collegefootball\n\n#coronavirus https://t.co/1GUc6cfWQG',
#   'username': 'big_mize'},
#  {'created_at': '2020-03-14 20:24',
#   'id': 1238923880561082368,
#   'text': 'If you your looking for something to help during these down months when athletes are everywhere- I suggest to emailing these  @Elite_Form and check their software out!!! #strengthcoach #NCAA https://t.co/gD2W2Fk2oN',
#   'username': 'Coach_Lanteigne'},
#  {'created_at': '2020-03-14 20:23',
#   'id': 1238923765024567297,
#   'text': '@espn How about #esports?  I’d love to see some of these #NCAA players face off in mic’d up live televised @NBA2K matches. 😊',
#   'username': 'ledbetter_jen'},
#  {'created_at': '2020-03-14 20:22',
#   'id': 1238923353114554369,
#   'text': 'Rush Spotlight 🔦\n“Push Pull”\n 💼 \n\n~\n\n#Sacks4Racks #PassRush #DefensiveLine #DLine #DL #NFL #CFL #NCAA #CollegeFootball #Football #Sack  #motivation #Hands https://t.co/i9f4i2UQGG',
#   'username': 'Sacks4Racks'},
#  {'created_at': '2020-03-14 20:20',
#   'id': 1238922884753620992,
#   'text': '#NCAA Will Consider Eligibility Relief for #Student-Athletes Affected by #COVID-19 Participation Ban https://t.co/QqOKcgpQfH',
#   'username': 'natlawreview'},
#  {'created_at': '2020-03-14 20:18',
#   'id': 1238922496600084480,
#   'text': '🤣😂🤣 As much as I wanted to be off work, I didn’t want to be on punishment with no sports watch on tv. 🤷🏽\u200d♂️😫🤦🏽\u200d♂️ #nba #ncaa #boxing #mlb \n\nWhat should I watch instead? @ Self Quarantine Homes https://t.co/wv4gSOMBvK',
#   'username': 'davoharris'},
#  {'created_at': '2020-03-14 20:17',
#   'id': 1238922193758814208,
#   'text': "Rick Pitino's college basketball coaching comeback will be made in his native New York at #IonaCollege. #NCAA #MarchMadness #marchmadness2020 #RickPitino @ICGaels @IonaMBB https://t.co/Zebc8bw7k6",
#   'username': 'Joe_Lombardi'},
#  {'created_at': '2020-03-14 20:16',
#   'id': 1238922083582828545,
#   'text': 'I really don’t care at this point that I’m listening to a year old #NCAA basketball game between Michigan and Mich State. I have to say @jimnance calling the game puts me in a good place. Maybe a rerun of a previous #Masters can air next on @CBSSports 🏀 🏌️ 🙏',
#   'username': 'KevinLynoWX'},
#  {'created_at': '2020-03-14 20:13',
#   'id': 1238921199088009219,
#   'text': '‼️🏀 Τι κι αν ο Ρικ Πιτίνο πριν μερικές ώρες ανέφερε στο twitter ότι θα ήθελε να προπονεί τους παίκτες του Παναθηναϊκού για όλη του τη ζωή... #paobc #panathinaikos #euroleague #ncaa #pitino https://t.co/LaUkyt0odU',
#   'username': 'olaprasina1908'},
#  {'created_at': '2020-03-14 20:11',
#   'id': 1238920624862617600,
#   'text': '2x National Championship winning head coach Rick Pitino will become the next coach of @IonaGaelsMBB of the @MAACSports #welcomeback #scandal #corona #virus #coronavirus #pitino #ncaa #collegebasketball #peytonsiva #patfacts #factspat #providence #kentucky #louisville #maaction https://t.co/w1LLNoRaXk',
#   'username': 'FactsPat'},
#  {'created_at': '2020-03-14 20:10',
#   'id': 1238920482067566602,
#   'text': 'Update.. #ncaa #bracketology #winner #basketball #ugh https://t.co/1hpwDSjVFp',
#   'username': 'weberspeakers'},
#  {'created_at': '2020-03-14 20:09',
#   'id': 1238920122766589956,
#   'text': 'Rick Pitino to Iona. #ncaa #collegebasketball',
#   'username': 'CoachKandJoe'},
#  {'created_at': '2020-03-14 20:08',
#   'id': 1238919985109622787,
#   'text': 'How will scholarships be impacted? Are schools going to tell incoming freshmen to hit the road to keep a fifth year stud? Messy. #NCAA https://t.co/7kO4YWltEn',
#   'username': 'KeatonInglis'},
#  {'created_at': '2020-03-14 20:07',
#   'id': 1238919746965385216,
#   'text': "I'm sure the #NCAA is familiar with liability waivers...\n\n@NCAAsoftball \n@NCAA",
#   'username': 'EricOchotnicki'},
#  {'created_at': '2020-03-14 20:04',
#   'id': 1238918899086823426,
#   'text': "@ReputationComm You're very kind but Can't take credit: Deadspin back in business (sidebar: UGH #notMyDeadspin) AND GUESS what 2 of recent posts were about? \n\n1) USWNT not getting respect \n2) WHY #B1G #BigTenConference won't keep MSU, Michigan U &amp; Ohio State accountable after reckoning #NCAA",
#   'username': 'TheOtherAllanWu'},
#  {'created_at': '2020-03-14 20:02',
#   'id': 1238918436475920384,
#   'text': 'it’s great that the #NCAA is granting another year of eligibility to spring athletes but that’s a problem for many reasons. 1st there won’t be enough scholarships for those seniors because their scholarship was promised to incoming freshmen. NCAA you giving more scholarships??',
#   'username': '_codybingham'},
#  {'created_at': '2020-03-14 20:02',
#   'id': 1238918365483278336,
#   'text': 'This no sports thing is so weird!! #XFL2020 #NCAA #NBA #NASCAR',
#   'username': 'KuszmaulDaniel'},
#  {'created_at': '2020-03-14 20:00',
#   'id': 1238917818181132288,
#   'text': 'How close are #Tennessee\nsports fans to wagering on their favorite #NFL, #NCAA, #NHL, #NBA, #MLB and #MLS teams?\n\nThe latest #sportsbetting developments in the Volunteer State:\n\nhttps://t.co/8UYSfWynOV',
#   'username': 'Gambling_USA'},
#  {'created_at': '2020-03-14 19:58',
#   'id': 1238917379532501004,
#   'text': "Take your shot at 4 seats to the 2021 NCAA Men's Final Four! Enter now through 4/6. #win #winners #giveaways #free #freebies #deals #ncaa #contests  #NABISCO #TogetherWeFan #Sweepstakes https://t.co/zQWEZZvuaP",
#   'username': 'contest_kween'},
#  {'created_at': '2020-03-14 19:58',
#   'id': 1238917362172276736,
#   'text': 'Rick Pitino has been hired by Iona to be their next HC. More to come. #NCAA #NCAAB #Iona #RickPitino',
#   'username': 'PSDnews'},
#  {'created_at': '2020-03-14 19:55',
#   'id': 1238916771962388485,
#   'text': "@charliekirk11 @NCAA I'm not sure if he accidentally overlooked my asking @charliekirk11 to help promote a petition to ask the  #NCAA to go from canceling games to just suspending them..\n\nI'm hoping so.. \n\nhttps://t.co/JT4PjF79lP",
#   'username': 'EricOchotnicki'},
#  {'created_at': '2020-03-14 19:54',
#   'id': 1238916351399321600,
#   'text': 'PAC-12 decides to cancel all sports competitions for the current academic year due to coronavirus concerns. #PAC12 #NCAA #covid19  https://t.co/bOY2cADz6g',
#   'username': 'noguchikealoha'},
#  {'created_at': '2020-03-14 19:53',
#   'id': 1238916202594000897,
#   'text': '205lb back squat today, just because the season is postponed does not mean the grind stops!!!🥎🥎🥎 @MacStephens @OhioStateSB @MizzouSoftball @KentStSoftball @Geneva_Softball @FinnUsb #softball #squat #stong #travelsoftball #grind #ncaa #mayfield #corners #powerhitter #power https://t.co/ClAsGBJynP',
#   'username': 'AngeleahSalten1'},
#  {'created_at': '2020-03-14 19:51',
#   'id': 1238915616469377024,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @reisner_steven: RT @BlueCollarMG: Should the #NCAA still release a bracket on #SelectionSunday ?? #MarchMadness',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 19:51',
#   'id': 1238915602485514241,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @thesportgene: RT @BlueCollarMG: Should the #NCAA still release a bracket on #SelectionSunday ?? #MarchMadness',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 19:51',
#   'id': 1238915571573497858,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @GoodOldBoysFF: RT @BlueCollarMG: Should the #NCAA still release a bracket on #SelectionSunday ?? #MarchMadness',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 19:51',
#   'id': 1238915557493268480,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @SteelCurtainPEH: RT @BlueCollarMG: Should the #NCAA still release a bracket on #SelectionSunday ?? #MarchMadness',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 19:50',
#   'id': 1238915522177249283,
#   'text': 'Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @JulianGuilarte1: RT @BlueCollarMG: Should the #NCAA still release a bracket on #SelectionSunday ?? #MarchMadness',
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-14 19:50',
#   'id': 1238915382695677952,
#   'text': "💥 #NCAA ekibi @IonaGaelsMBB'da başantrenörlüğe Rick Pitino'nun getirilmesi bekleniyor. \n\nhttps://t.co/b8Wr53hg9e",
#   'username': 'YarisahaBasket'},
#  {'created_at': '2020-03-14 19:50',
#   'id': 1238915354220470272,
#   'text': 'Crazy thought: since sports tv stations won’t have much to talk about with the suspension of the #NBA #mlb #ncaa then they should fill their airwaves with local and national political commercials. It allows candidates w/o huge pockets to get fair airtime. https://t.co/rSvHQTJ5ZE',
#   'username': 'Daniel__France'},
#  {'created_at': '2020-03-14 19:46',
#   'id': 1238914366046699521,
#   'text': "My heart goes out to all the guys that are going through with thier March Madness-less vasectomies... y'all are the real hero's.   #NCAA #MarchSadness #MarchMadness #barstoolsports #barstoolnosports #coronapocalypse #CoronavirusUSA",
#   'username': 'drwebgem'},
#  {'created_at': '2020-03-14 19:45',
#   'id': 1238914153940692992,
#   'text': 'Oh good.\nGod forbid some younger coach got an opportunity.\n#NCAA #ReduceOpportunity #ReuseTheSameCriminals #RecycleTerribleHiringStandards https://t.co/tsDXmVmLOr',
#   'username': 'BVielhaber'},
#  {'created_at': '2020-03-14 19:45',
#   'id': 1238914149121495041,
#   'text': "We'll be playing our own NCAA Tournament @DigSportsDesk #NCAA #FinalFour https://t.co/gT55F0W7ik",
#   'username': 'terrylyons'},
#  {'created_at': '2020-03-14 19:39',
#   'id': 1238912558641426433,
#   'text': 'Watching re-airs of basketball games just isn’t the same. Who knew that when I went to see TCU and Oklahoma play last Saturday was my last time seeing a NCAA college basketball game. This shit feels eerie as heck. #NCAA #coronapocalypse #basketball',
#   'username': 'ugilbert02'},
#  {'created_at': '2020-03-14 19:38',
#   'id': 1238912289648136198,
#   'text': 'Looking for a sports show to watch today? Well check out our latest episode of #SportsvisionsTVShow on YouTube! https://t.co/VNmcpXJTgE #MarchMadness #NCAA #Sports #NBA #basketball #coronavirus https://t.co/qhwcUFqauI',
#   'username': 'SportsvisionsUS'},
#  {'created_at': '2020-03-14 19:36',
#   'id': 1238911865272614918,
#   'text': 'I still can’t believe we didn’t wake up today to watch college hoops 🏀. There is no closure. I hope they find a way to celebrate &amp; honor the players especially the Seniors in due time. #kubball #MarchMadness #NCAA #coronavirus #kucmb #marchsadness',
#   'username': 'RockChalknNYC'},
#  {'created_at': '2020-03-14 19:34',
#   'id': 1238911308885643265,
#   'text': 'This Was March. Took this pic Tuesday night knowing it might be awhile...\n\n#NCAA #MarchMadness #coronavirus https://t.co/soXk7CEHPP',
#   'username': 'TheEliteDJB'},
#  {'created_at': '2020-03-14 19:33',
#   'id': 1238911215507734529,
#   'text': 'Should NCAA college athletes be able to make money off of their Name, Image and Likeness? Ohio State Athletic Director Gene Smith tells us his thoughts on this and much more in Episode 16 of the Pilot Boys Podcast. Full interview here: https://t.co/EIoseyU8wc #NCAA #NIL #OSU https://t.co/mMvH35E5BM',
#   'username': 'pilotboyspod'},
#  {'created_at': '2020-03-14 19:29',
#   'id': 1238910042772045825,
#   'text': 'Sources: Rick Pitino a candidate for Iona job\n\nhttps://t.co/YzX0EAmhIw\n\n#NCAA #ncaabasketball #iona #ionabasketball #RickPitino https://t.co/h7Ov9P72II',
#   'username': 'WWSRN_Radio'},
#  {'created_at': '2020-03-14 19:28',
#   'id': 1238909915286159360,
#   'text': 'Omg I found a link to a secret stream of the Big Ten Tournament games they said were cancelled! We were lied to\nhttps://t.co/kEtJbXBOqd\n#NCAA #MarchMadness #CoronaVirusUpdates #bigten',
#   'username': 'ryan_defrance'},
#  {'created_at': '2020-03-14 19:24',
#   'id': 1238908959609614336,
#   'text': 'What’s the over/under for when they go on probation. The guy is pure slime. #NCAA #RickPitino #menshoop #probation https://t.co/inJAHH4sC0',
#   'username': 'golferinatlanta'},
#  {'created_at': '2020-03-14 19:24',
#   'id': 1238908803602677760,
#   'text': "Happy #314day \n\nFrom @314SportsTalk \n\nStay tuned for our upcoming commercial done by renaissancetjs \n\nSt.Louis, we are about to make y'all PROUD!!\n\n#MLB #NCAA #NHL #NBA #WWE #STL #xfl #ThePlatformSportsTalkShow… https://t.co/MpYZAaf52X",
#   'username': '314SportsTalk'},
#  {'created_at': '2020-03-14 19:20',
#   'id': 1238907794025308161,
#   'text': '🔥Ένα τιτίβισμα, που ανάβει φωτιές!\n https://t.co/oOgiCDzjXB \n#panathinaikos #pitino #ncaa https://t.co/MS9qWDjCZo',
#   'username': 'novasportsgr'},
#  {'created_at': '2020-03-14 19:18',
#   'id': 1238907261218676737,
#   'text': '#corona #coronavirus #covid_19 #marchmadness #marchmadness2020 #ncaabasketball #ncaa #nba #mlb #nhl #uefa #comic #meme #webcomic #sketch #drawing #doodle #ink #inking #dog #cat https://t.co/SYFTBxvhrS https://t.co/oPVnGi8kfG',
#   'username': 'kevinlsample'},
#  {'created_at': '2020-03-14 19:14',
#   'id': 1238906337603485697,
#   'text': "Florida state senator Joe Gruters introduced a resolution that passed on Friday declaring #FloridaStateUniversity as the 2020 #NCAA basketball national champions due to the NCAA's decision to cancel #MarchMadness https://t.co/cWzJEe0WYq",
#   'username': 'JDFSports'},
#  {'created_at': '2020-03-14 19:11',
#   'id': 1238905729651814409,
#   'text': 'For sports fans, is 2020 going to be known as the dark ages? #MLB #NBA #NHL #NCAA #PGA #WeNeedSports',
#   'username': 'TheTokingLion'},
#  {'created_at': '2020-03-14 19:10',
#   'id': 1238905381025349633,
#   'text': '#Oklahoma running back Trey Sermon has enter the #NCAA transfer portal, he rushed for over 2,000 yards and had 22 touchdowns as a #Sooner https://t.co/KvsTKLzYA7',
#   'username': 'JDFSports'},
#  {'created_at': '2020-03-14 19:07',
#   'id': 1238904513563590656,
#   'text': 'The NCAA is looking to extend another year for spring athletes so they can play their extra seasons. #CoronaVirusUpdates #spring2020 #athletes #NCAA',
#   'username': 'TMuslusky'},
#  {'created_at': '2020-03-14 19:05',
#   'id': 1238903976176668672,
#   'text': "How sweet it is! @HofstraMBB wins the @CAASports men's #basketball tournament over @GoNUmbasketball.\n\nSee story by @Broookksss and photos from @CoryRoyster: https://t.co/Yk9Orp8MM3\n\n#CAAHoops #CAAChamps #CollegeBasketball @Jose_M_Umana @PCBlueHose43 #NCAA https://t.co/IXNoCMcE1u",
#   'username': 'the_sportspulse'},
#  {'created_at': '2020-03-14 19:02',
#   'id': 1238903415364816900,
#   'text': "COLUMN: A sports fan's guide to getting by the next several weeks without live sports events on TV: #NCAA #NBA #MLB #NFL #Masters #Eagles #Caddyshack https://t.co/ZdQfQ8d7Dl via @delawareonline",
#   'username': 'Mfranknfl'},
#  {'created_at': '2020-03-14 19:00',
#   'id': 1238902794095964160,
#   'text': "https://t.co/YQpOtMw6ag  \n\nSissy's Grade 10 highlight tape! #Basketball #Recruits #Sports #NCAA",
#   'username': 'MrRoderickI'},
#  {'created_at': '2020-03-14 19:00',
#   'id': 1238902760550076418,
#   'text': 'Badgers the LAST team in??? At least they would have made it. 🤷🏾\u200d♂️ #NCAA https://t.co/sIKOowH0px',
#   'username': 'the20double'},
#  {'created_at': '2020-03-14 18:59',
#   'id': 1238902677859381248,
#   'text': '@masnRoch good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:54',
#   'id': 1238901314735812608,
#   'text': '@antwanstaley good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:54',
#   'id': 1238901207315423235,
#   'text': '@JasonLaCanfora good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:52',
#   'id': 1238900716455985154,
#   'text': 'UConn’s Walker to forgo senior year, enter WNBA draft https://t.co/jEZRPI0LJg #ncaa',
#   'username': 'nicholasanorman'},
#  {'created_at': '2020-03-14 18:52',
#   'id': 1238900715478810625,
#   'text': 'Syracuse freshman guard Brycen Goodine to transfer https://t.co/vEPQm68PLK #ncaa',
#   'username': 'nicholasanorman'},
#  {'created_at': '2020-03-14 18:51',
#   'id': 1238900696398921733,
#   'text': '@notthefakeSVP  good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:51',
#   'id': 1238900614131744769,
#   'text': '@AnthonyCowanJr @Jeff_Ermann good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:51',
#   'id': 1238900611564871682,
#   'text': "Don't know if it's a thing but enterprising folks should stream street basketball games (&amp; other sports) on Twitch since the pro sports are canx #COVID19 #COVIDー19 #SportsRelief2020 #NBA #twitch #ESPN #MarchMadness #NCAA",
#   'username': 'NightDragon1776'},
#  {'created_at': '2020-03-14 18:50',
#   'id': 1238900388956340226,
#   'text': '@Jeff_Ermann good win last night @TerrapinHoops Way to keep it up. Win it all tomorrow!! #Imagination #NCAA #basketball',
#   'username': 'MB4slow'},
#  {'created_at': '2020-03-14 18:42',
#   'id': 1238898353548582913,
#   'text': '🚨New video just dropped on YouTube🚨 How is the cancellation of #MarchMadness going to affect #NCAA eligibility? How are the #NHL and #NBA playoffs going to work now? Find out what we think. \nhttps://t.co/KLbcUZoJEP',
#   'username': 'FourthLongRadio'},
#  {'created_at': '2020-03-14 18:41',
#   'id': 1238898103874289666,
#   'text': 'I’ve now lived the life of those people who don’t follow or enjoy sports for about 15 hours. To each his own, but I’ll pass. Serenity now. #MHSA #MLB #NCAA #Masters',
#   'username': 'david_peretto'},
#  {'created_at': '2020-03-14 18:36',
#   'id': 1238896910645243904,
#   'text': 'Episode 60 of #BleacherBlums \n\nThese are some crazy times we’re living in.  Let @realdavidtuttle &amp; I update you on #MLB #NBA #NCAA #NFL Covid-19 news &amp; ideas. We also recap @BachelorABC season with a very special guest.  #BelieveIt https://t.co/ypRTRABEwg',
#   'username': 'blummer27'},
#  {'created_at': '2020-03-14 18:36',
#   'id': 1238896828206198789,
#   'text': 'LOL.... Amazing the greed in the world. #Apple, #Nike, nor #Microsoft  has an emergency plan from the enforced #China labor. Why? Viruses come &amp; go, BILLIONS will still be made. #NCAA https://t.co/u022psTgl3',
#   'username': 'WTH_inthe'},
#  {'created_at': '2020-03-14 18:35',
#   'id': 1238896475368763392,
#   'text': 'We had so much confidence in @BarackObama it’s crazy.\n\nDuring his presidency we had:\n* Influenza \n* Hantavirus \n* Enterovirus\n* Ebola\n* Zika\n\nThe #NBA, #NHL, #NCAA, #Coachella, #gaypride March, Schools..etc never cancelled &amp; we still had record growth in the #StockMarket.',
#   'username': 'ro_saun'},
#  {'created_at': '2020-03-14 18:33',
#   'id': 1238896140050993154,
# ...
#   'id': 1238496660159967233,
#   'text': '#NCAA cancels all winter and spring championships as #coronavirus spreads across US https://t.co/mb222GqlNn #MarchMadness #NCAA #CollegeSports',
#   'username': 'insidethegames'},
#  {'created_at': '2020-03-13 16:02',
#   'id': 1238495581330231296,
#   'text': 'I was so excited to make a bracket this year after 4 years of not being allowed. #NCAA #DontBetOnIt',
#   'username': 'DrewSavage8'},
#  {'created_at': '2020-03-13 16:01',
#   'id': 1238495354460557314,
#   'text': 'The @bethelxctf team has been running out of their shoes during the outdoor season. Macie Gavic wrote a story about it check it out. @NCAADIII #Trackandfield #d3sports #ncaa #4x400 #running https://t.co/cNKas4loOh',
#   'username': 'joehiti'},
#  {'created_at': '2020-03-13 16:00',
#   'id': 1238495256095719426,
#   'text': "cable companies to ESPN:\nWe're paying you how much what for exactly what now?\n#NBA #MLB #NCAA #MarchSadness @RichLightShed https://t.co/d8ZO2u4nJP",
#   'username': 'robenfarzad'},
#  {'created_at': '2020-03-13 16:00',
#   'id': 1238495184373022720,
#   'text': "Make sure you subscribe to Guys Talkin' Sports on the Google Podcast - https://t.co/Rtex8SMdYP #NBA #podcast #NFL #NCAA #bestsportspodcast",
#   'username': 'iamalquarles'},
#  {'created_at': '2020-03-13 16:00',
#   'id': 1238495040349011969,
#   'text': 'As NBA and NCAA Go Dark, Turner and CBS Brace For Losses | Hollywood Reporter\nhttps://t.co/OkL4bsbUSW\n\n#coronavirus #covid19 #nba #ncaa #turner #cbs #studio #loss #tv #tvnews https://t.co/91XLZ8UyBq',
#   'username': 'filmjammer'},
#  {'created_at': '2020-03-13 15:59',
#   'id': 1238494858035298304,
#   'text': 'Never going to take practice/play like it could be your last day doing it for granted ever again. To step on the field is a true blessing and to see people so close to my heart have it taken away hurts. #Covid_19 #NCAA @NCAA @TheGNAC',
#   'username': 'aircad3n'},
#  {'created_at': '2020-03-13 15:58',
#   'id': 1238494715231776769,
#   'text': '🚨New Episode🚨 Episode 50 of Sports Talk Buffalo is out now!!! This week I will talk about the @BuffaloBills offseason needs/FA signings and in segment 2 I will break down how I felt @jim_whitesell did in his first year\n#UBhornsUP #NCAA #Bills #NFL #Draft\nhttps://t.co/DLG8RhcP8w',
#   'username': 'Sportstalkbuff1'},
#  {'created_at': '2020-03-13 15:57',
#   'id': 1238494448855777280,
#   'text': 'How ironic is this meme right now considering it was a pair of Jazz hands that shut down the #NBA #NCAA https://t.co/ZjklMiw8XG',
#   'username': 'Demonpenz'},
#  {'created_at': '2020-03-13 15:56',
#   'id': 1238494075499810821,
#   'text': 'For all #NCAA #MarchMadness fans, try this great bracket.  Fill it out and follow along.  Fun, and great for creative inspiration!  @SportandStoryBo @PhilElsonPxP https://t.co/HzO7HurMvV',
#   'username': 'fayvineyards'},
#  {'created_at': '2020-03-13 15:55',
#   'id': 1238494020357296130,
#   'text': 'I’m not sure how I’m processing all of this. I don’t think it’s hit me yet that there will be no sports happening for a while. Onward to cleaning, CEUs, and becoming Dr. Benz!\n\n#AthleticTrainer\n#NCAA\n#NATM2020\n#JourneyToDrBenz',
#   'username': 'MemoriaVitae'},
#  {'created_at': '2020-03-13 15:55',
#   'id': 1238493857873948674,
#   'text': 'Caleb Keller of @TVG talks @TurfwayPark Jeff Ruby stakes. Our talk starts at 40:00, We discuss Disappointment in the #NCAA Tourney getting shut down. Then at 44:40 we break down the Jeff Ruby &amp; @calebtvg gives an undercard play \n\nhttps://t.co/8332Q52yH3\n\nhttps://t.co/5e57UchWHK https://t.co/36NjhXBhgF',
#   'username': 'ItsMeGinoB'},
#  {'created_at': '2020-03-13 15:55',
#   'id': 1238493838962036736,
#   'text': 'The NCAA should grant eligibility to all seniors that are college athletes #ncaa #coronavirus #collegestudentathlete https://t.co/z5szfrijtQ',
#   'username': 'DJ_Mike_Larry'},
#  {'created_at': '2020-03-13 15:54',
#   'id': 1238493592265654273,
#   'text': 'LRTs\nBe careful out their amateur player. While your season may be on hold, High school and #NCAA compliance issues are not suspended due to COVID. \n\nDon’t go play with your summer team or go to “showcases” until all cleared.',
#   'username': 'jtknipp'},
#  {'created_at': '2020-03-13 15:52',
#   'id': 1238493191965376513,
#   'text': '@NCAA for spring sport players in the final year of eligibility, would they still have that year of eligibility next year? Essentially treat this cancelled season as a redshirt for everyone? #CoronavirusPandemic #NCAA',
#   'username': 'NotAJetson'},
#  {'created_at': '2020-03-13 15:50',
#   'id': 1238492736837353473,
#   'text': "Yo check out Hurricane by @__knowlej__ https://t.co/bjgX1Rw0Oo RT @danangell11: Screw it. If the #NCAA won't do it, I'm going to decide my own bracket on #SelectionSunday. Why the hell not?",
#   'username': 'Azn_b_u_t'},
#  {'created_at': '2020-03-13 15:48',
#   'id': 1238492108887113728,
#   'text': "As a former student-athlete myself, I can't imagine what some of them are going through right now. If there is anything I can do to help, please don't hesitate to reach out. You're not alone... 🙏\n\n#FanWord #smsports #NCAA #coronavirus",
#   'username': 'Chris_Aumueller'},
#  {'created_at': '2020-03-13 15:48',
#   'id': 1238492090046152705,
#   'text': 'I was hoping to wake up this morning and find that yesterday was a weird, sad, uncomfortable, long, heartbreaking dream. But here we are. #NCAA',
#   'username': 'CoachCurly_'},
#  {'created_at': '2020-03-13 15:46',
#   'id': 1238491649229099008,
#   'text': 'My thoughts on the #sports shutdown and opportunity we have to show our #studentathletes that their worth is not tied to sports performance. @USLacrosse @USLacrosseMag @NCAA \n#lacrosse #ncaa #bigten #sportsperformance #sportsmanagement #parentingskills\nhttps://t.co/9RDmkWMPhC',
#   'username': 'LaurenFaby'},
#  {'created_at': '2020-03-13 15:44',
#   'id': 1238491218184671232,
#   'text': '#kag #nascar #ncaa #tpc #pga #nba And just like that, all the fun was taken away! https://t.co/ktu8808Sa5',
#   'username': 'DavidHouston54'},
#  {'created_at': '2020-03-13 15:43',
#   'id': 1238490794052501504,
#   'text': "Screw it. If the #NCAA won't do it, I'm going to decide my own bracket on #SelectionSunday. Why the hell not?",
#   'username': 'danangell11'},
#  {'created_at': '2020-03-13 15:40',
#   'id': 1238490218191376384,
#   'text': '••• PLEASE READ ••• \nGYM Sportsbar remains OPEN and vigilant in protecting the health and safety of our customers and employees.\n\nThank You.\n.\n.\n\n#gymsportsbarny #gym #gymbar #weekend #sports #athletics #fans #NCAA… https://t.co/m6KsmoYdD8',
#   'username': 'GYMSPORTSBARNY'},
#  {'created_at': '2020-03-13 15:40',
#   'id': 1238490164663439361,
#   'text': 'Really the worst part of this sports hiatus is the Seniors in #NCAA sports that had a proper send off planned for their last home game. And that was cut short. I can’t imagine how devastating that is.',
#   'username': 'OGbobbyjohnston'},
#  {'created_at': '2020-03-13 15:40',
#   'id': 1238489998111977474,
#   'text': 'Seven #Pitt wrestlers had qualified for the #NCAA Tournament scheduled to begin March 19 in Minneapolis. The @NCAA canceled all winter and spring championships\nhttps://t.co/sdUv6bk3fl',
#   'username': 'TribSports'},
#  {'created_at': '2020-03-13 15:38',
#   'id': 1238489711674626050,
#   'text': 'https://t.co/wWwgVJRimC #NCAA @NCUSAW @NC_Wrestling @WrestleNC @NCWRSTLCOACHES @NCWresReport @nchsaawrestle @NCAWA_Info @NCwrestlePolls @DHWrestleNC',
#   'username': 'CarolinasMat'},
#  {'created_at': '2020-03-13 15:37',
#   'id': 1238489274875510790,
#   'text': 'Since I submitted a blank bracket for March Madness, am I the first person ever to have a perfect bracket? #MarchMadness #MarchSadness #NCAA',
#   'username': 'Tommy2Wheels'},
#  {'created_at': '2020-03-13 15:37',
#   'id': 1238489249101615106,
#   'text': 'The #NCAA March Madness tournament, the finale of the college basketball season, has been cancelled due to #COVID19. The announcement came a day after the #NBA suspended the 2020 season. \n\nRead more via @TheOdyssey: https://t.co/ZpB11aXY6h',
#   'username': 'action'},
#  {'created_at': '2020-03-13 15:36',
#   'id': 1238489234337681408,
#   'text': '#NCAA #NCAABasketball #NCAATournament #NCAABaseball #CancelEverythingNow https://t.co/PtMnlk8DYt',
#   'username': 'FQTulane'},
#  {'created_at': '2020-03-13 15:36',
#   'id': 1238489161004433408,
#   'text': '#statoftheday:\nThis season will be the first to not declare a NCAA champion in basketball since the tournament began in 1939.\n\n#NCAA',
#   'username': 'jdfletch3'},
#  {'created_at': '2020-03-13 15:35',
#   'id': 1238488858699980802,
#   'text': 'Feel bad for everyone affected ! Don’t take their dream ! \nNCAA: Reschedule NCAA Wrestling Tournament - Sign the Petition! https://t.co/4bRWnBYN3a via @Change \n#ncaa #wrestling #mma #fixitfast',
#   'username': 'Cohimma'},
#  {'created_at': '2020-03-13 15:35',
#   'id': 1238488741385207813,
#   'text': 'Confirmed: Bram Scheerer (F) | Minnesota Wilderness -&gt; Union College | https://t.co/G2RP7M37sz #NCAA',
#   'username': 'ep_transfers'},
#  {'created_at': '2020-03-13 15:34',
#   'id': 1238488518051221505,
#   'text': '#NCAA champ this year is #Covid_19',
#   'username': 'TheNobleTaco'},
#  {'created_at': '2020-03-13 15:33',
#   'id': 1238488388728217602,
#   'text': "I'm pretty sure if you asked any college athlete out there they'd rather take the 2% chance of getting coronavirus instead of cancelling their entire season and crushing their dreams. Wake up #NCAA",
#   'username': 'Hunter_Buckshot'},
#  {'created_at': '2020-03-13 15:33',
#   'id': 1238488276178046976,
#   'text': '#NCAA #SantaClara Lets promote this for all the Senior Athletes! https://t.co/DWkX4lhZK7',
#   'username': 'showard50'},
#  {'created_at': '2020-03-13 15:32',
#   'id': 1238488134054293506,
#   'text': 'Well said Coach! #L1C4 #NCAA #MarchSadness #Louisville https://t.co/6hQcFuiZvd',
#   'username': 'Tres_MAFS'},
#  {'created_at': '2020-03-13 15:30',
#   'id': 1238487509958643713,
#   'text': 'So True !! \n#NewYork #ncaa #coronapocalypse #FridayThe13th #nba #FridayThoughts #FridayFeeling https://t.co/kw3zXBkd8k',
#   'username': 'ace292325'},
#  {'created_at': '2020-03-13 15:28',
#   'id': 1238487185516572674,
#   'text': "@LibsInAmerica Don't forget the #NBA #NHL #MLB #NCAA #Italy #WashingtonState... 🤔",
#   'username': 'darkwriter'},
#  {'created_at': '2020-03-13 15:27',
#   'id': 1238486804908531713,
#   'text': '@GovSisolak declares a state of emergency in Las Vegas over coronavirus.  I’d like to remind him the Jeffry Dahmer ate more people than have it  in this state.  Cancelling the #NCAA Championship after they were already here for 48 hours but allowing the Post Malone concert????',
#   'username': 'VegasNativeToo'},
#  {'created_at': '2020-03-13 15:26',
#   'id': 1238486500469133312,
#   'text': 'Funny No Sports March Memes\nhttps://t.co/rEeUho1ga6\n#nosports #nhl #nhlsuspended #mlb #mlbsuspended #mls #mlssuspended #nba #nbasuspended #nbaseasonsuspended #sports #coronavirus #covid19 #nofootball #ncaa #boredaf #marchsadness #marchmadness #pgatour',
#   'username': 'lifeslurp'},
#  {'created_at': '2020-03-13 15:26',
#   'id': 1238486479925587968,
#   'text': 'Spring Training 🙃🙃 #northtorontobaseball #torontobaseball #offseasontraining ___________________  #collegebaseball #prospect #NCAA #NAIA  #trainingmode  #EliteBaseball #bluejaysbaseball #baseballacademy #MLB… https://t.co/x09cyhykRt',
#   'username': 'RINGSZN16'},
#  {'created_at': '2020-03-13 15:24',
#   'id': 1238486181958082560,
#   'text': "This Sunday March 15th! We're at it again, as myself &amp; #SoulBowl are teaming up to give you some #BrunchMadness! Now, we know the #NCAA #MarchMadness #Tournament has been cancelled,  but we'd like to lift your… https://t.co/JAcju4ksuO",
#   'username': 'A_Quil22'},
#  {'created_at': '2020-03-13 15:24',
#   'id': 1238486051330633728,
#   'text': '@jppalmCBS The good thing is, the #NCAA administration isn’t working currently so questions like these can be answered properly',
#   'username': 'DSports24'},
#  {'created_at': '2020-03-13 15:22',
#   'id': 1238485478401363968,
#   'text': 'Confirmed: Jake Bongo (F) | Selects Hockey Academy 16U -&gt; Sacred Heart Univ. | https://t.co/IyjboEyAAO #NCAA',
#   'username': 'ep_transfers'},
#  {'created_at': '2020-03-13 15:19',
#   'id': 1238484935805108226,
#   'text': 'Nice work by @RMFieldHouse which is paying all event staff for #Cavs, #Monsters, #Charge, #NCAA and #MAC tournaments and concerts as if they are being held.',
#   'username': 'twithersAP'},
#  {'created_at': '2020-03-13 15:16',
#   'id': 1238484205769760769,
#   'text': 'How many people got burned buying #NCAA futures tickets on prop swap with #NCAATournament being cancelled? Ouch, those Dayton and San Diego state buyers... @North2North',
#   'username': 'BetsToLiveBy'},
#  {'created_at': '2020-03-13 15:16',
#   'id': 1238484005126840322,
#   'text': '#TheMastersTournament #TheMasters #Golf #BostonMarathon2020 #BostonMarathon #NCAA #XFL2020 #XFL\nhttps://t.co/cPxjiLulCI',
#   'username': 'clubseatnetwork'},
#  {'created_at': '2020-03-13 15:15',
#   'id': 1238483936537448449,
#   'text': '"The NCAA needs to be better run, leadership change actually should be on the table." \n\n@JayBilas is out here telling the #NCAA what’s up. He’s also pushing for another year of eligibility for seniors who didn’t get the chance to play in #MarchMadness. That may be hard to do IMO.',
#   'username': 'hathawaygeorge9'},
#  {'created_at': '2020-03-13 15:15',
#   'id': 1238483764084445184,
#   'text': 'I agree with this. The yes men and women over @espn were lobbying against it today. I guess their bosses told them how to think about this too. It’s interesting how anti young people espn is. @wingoz @MGolicJR57 @espngolic #NCAA https://t.co/u6HjCYBle1',
#   'username': 'TheCardSlinger'},
#  {'created_at': '2020-03-13 15:12',
#   'id': 1238483145927901185,
#   'text': 'Should the NCAA grant seniors another year of eligibility?\n\nVote and Retweet\n\n#NCAA #MarchMadness #CoronaVirus',
#   'username': 'TimeoutSPORTS3'},
#  {'created_at': '2020-03-13 15:12',
#   'id': 1238482992466714624,
#   'text': '#TheMastersTournament #TheMasters #Golf #BostonMarathon2020 #BostonMarathon #NCAA #XFL2020 #XFL\nhttps://t.co/aFPHCtZ6Gx',
#   'username': 'edrobinson82'},
#  {'created_at': '2020-03-13 15:12',
#   'id': 1238482965799133197,
#   'text': 'Looking forward to watching the races and meeting with many talented student athletes tomorrow. If you want to learn more about university in the USA come and see us!\n-\n#ncaa #sports #englishschools #xc… https://t.co/xD45hT8Zfl',
#   'username': 'Sporting_Elite'},
#  {'created_at': '2020-03-13 15:11',
#   'id': 1238482869737213959,
#   'text': 'Dream denied: Virus dashes Dayton’s magical hoops season https://t.co/5CQqlWlkSF #ncaa',
#   'username': 'nicholasanorman'},
#  {'created_at': '2020-03-13 15:11',
#   'id': 1238482745317371904,
#   'text': 'We the people should vote on if the NCAA seniors in ALL SPORTS would be eligible to play again next year, not someone who just gives a shit about how much money they making. #NCAA',
#   'username': 'JJstoelzl'},
#  {'created_at': '2020-03-13 15:10',
#   'id': 1238482640321286147,
#   'text': 'This is irrelevant in comparison to the health &amp; safety of population as a whole. That’s what is important rn. We should all be making preparations. \n\nBut it is a damn shame for those kids who’ve poured out their hearts&amp;souls in pursuit of a dream. 2/2\n\n#NCAA \n#coronapocolypse',
#   'username': 'APRoth19'},
#  {'created_at': '2020-03-13 15:09',
#   'id': 1238482322053386241,
#   'text': 'Literally the only thing that I look forward too in sports is fucking cancelled. Over less than the common cold. #NCAA Thanks for the #MarchSadness 🤬🤬🤬',
#   'username': 'FelicityRusnak'},
#  {'created_at': '2020-03-13 15:08',
#   'id': 1238482043773878275,
#   'text': 'There’s growing sympathy and support for all student athletes whose seasons were devastated by the #CoronavirusPandemic \n\nShould students be granted another year of athletic eligibility by NCAA? \n\nDid #ncaa pull the plug too quickly on @marchmadness \n\nhttps://t.co/l9nczrGcle',
#   'username': 'ShadowLeague'}]
